# %% [markdown]
# # Based on Basic animation with FuncAnimation
# https://riptutorial.com/matplotlib/example/23558/basic-animation-with-funcanimation
#
# Let's animate a dot moving around an ellipse

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation, FFMpegWriter
# %matplotlib notebook
# set up figure size and DPI for screen demo
plt.rcParams['figure.figsize'] = (7, 7)
plt.rcParams['figure.dpi'] = 100

# %%
TWOPI = 2*np.pi # numpy doesn't have tau (2π)

fig, ax = plt.subplots()

# h&k are offsets from the origin for later use when setting a star at a focus
h = k = 0.0                          # for now, the center of the ellipse is the origin
a = b = 1.0                          # for now, the semimajor axis, a & semiminor axis, b = 1
theta = np.arange(0.0, TWOPI, 0.001) # ø values from 0 to π in increments of 0.001
x = h + a*np.cos(theta)                    # x values from -1 to 1
y = h + b*np.sin(theta)                    # y values from -1 to 1
l = plt.plot(x, y)                   # x,y plot of t,s values
ax = plt.axis([-2,2,-2,2]) # plt.axis([xmin, xmax, ymin, ymax]) equivalent to ax.set(xlim=(xmin, xmax), ylim=(ymin, ymax))

redDot, = plt.plot([np.cos(0)], [np.sin(0)], 'ro')

# plt.plot

def animate(i):
    redDot.set_data(np.cos(i), np.sin(i))
    plt.title('radians: {:^2.1f}'.format(i))
    return redDot,

# create animation using the animate() function
progress_callback = lambda i, n: print(f'Saving frame {i+1} of {n}')
animation = FuncAnimation(fig, animate, frames=np.arange(0.0, TWOPI, 0.1), interval=50, blit=True, repeat=False)

# animation = FuncAnimation(plt.gcf(), #get current figure or gcf
#                           update, #the function to update
#                           frames=frames, #overrides the default frames behavior of counting up i in integers from 0
#                           interval=interval,
#                           #repeat = False, #option to stop animation after one iteration
#                           repeat_delay = 2e3, #optional delay in ms; 1e3 = 1000 ms = 1 s
#                           #progress_callback=progress_callback
#                           )


# from matplotlib.animation import FFMpegWriter
writer = FFMpegWriter(fps=15, metadata=dict(artist='Stephen Shadle'), bitrate=1800)
#ani.save("/home/pi/Documents/Thonny/dynamic_image.mp4", writer=writer) #explicit directory
animation.save("animate_circle2.mp4", writer=writer, progress_callback=progress_callback) #current directory
# plt.show()
# Out:
# <img src="data:image/png;base64,..." width="700">
# Saving frame 1 of 63
# Saving frame 2 of 63
# Saving frame 3 of 63
# Saving frame 4 of 63
# Saving frame 5 of 63
# Saving frame 6 of 63
# Saving frame 7 of 63
# Saving frame 8 of 63
# Saving frame 9 of 63
# Saving frame 10 of 63
# Saving frame 11 of 63
# Saving frame 12 of 63
# Saving frame 13 of 63
# Saving frame 14 of 63
# Saving frame 15 of 63
# Saving frame 16 of 63
# Saving frame 17 of 63
# Saving frame 18 of 63
# Saving frame 19 of 63
# Saving frame 20 of 63
# Saving frame 21 of 63
# Saving frame 22 of 63
# Saving frame 23 of 63
# Saving frame 24 of 63
# Saving frame 25 of 63
# Saving frame 26 of 63
# Saving frame 27 of 63
# Saving frame 28 of 63
# Saving frame 29 of 63
# Saving frame 30 of 63
# Saving frame 31 of 63
# Saving frame 32 of 63
# Saving frame 33 of 63
# Saving frame 34 of 63
# Saving frame 35 of 63
# Saving frame 36 of 63
# Saving frame 37 of 63
# Saving frame 38 of 63
# Saving frame 39 of 63
# Saving frame 40 of 63
# Saving frame 41 of 63
# Saving frame 42 of 63
# Saving frame 43 of 63
# Saving frame 44 of 63
# Saving frame 45 of 63
# Saving frame 46 of 63
# Saving frame 47 of 63
# Saving frame 48 of 63
# Saving frame 49 of 63
# Saving frame 50 of 63
# Saving frame 51 of 63
# Saving frame 52 of 63
# Saving frame 53 of 63
# Saving frame 54 of 63
# Saving frame 55 of 63
# Saving frame 56 of 63
# Saving frame 57 of 63
# Saving frame 58 of 63
# Saving frame 59 of 63
# Saving frame 60 of 63
# Saving frame 61 of 63
# Saving frame 62 of 63
# Saving frame 63 of 63

# %%
# ?FuncAnimation
