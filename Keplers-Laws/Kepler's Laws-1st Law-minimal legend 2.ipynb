# %%
""" Kepler's Laws-1st Law
6m two-loop pass to grow then shrink the shaded areas
Trying out different formulae. This one works with e up to 0.95. It breaks for 0.99
Calculation and animation of eccentric and true anomalies from mean anomaly
"""
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.legend_handler import HandlerPatch
from matplotlib.animation import FuncAnimation
from matplotlib.animation import FFMpegWriter
import matplotlib.patches as mpatches
from matplotlib.collections import PatchCollection
from math import floor, factorial
# %matplotlib notebook
with plt.xkcd():
    from matplotlib import patheffects
    plt.style.use(['dark_background'])
    plt.xkcd()
    plt.rcParams['path.effects'] = [patheffects.withStroke(linewidth=0)]
    plt.rcParams['figure.facecolor'] = 'black'
    # explanation of path.sketch from the docstring of the xkcd function
    # scale = 1  # amplitude of the wiggle
    # length = 100  # length of the wiggle along the line
    # randomness = 2  # scale factor for shrinking and expanding the length
    plt.rcParams['path.sketch'] = (0.6, 100, 2)

    TWOPI = 2*np.pi # numpy doesn't have tau (2π)

    plt.style.use('dark_background')
    fig = plt.figure(figsize=(6.7, 5), dpi=100)
    # xyticklabels=[-2,-1,0,1,2]
    xyticklabels=[]
    ax = plt.subplot(1,1,1,frameon=False,xticks=xyticklabels,yticks=xyticklabels,xlim=(-1.05,1.8),ylim=(-1.1,1.1))
    ax.set_yticklabels(xyticklabels)
    ax.set_xticklabels(xyticklabels)

    # e is eccentricity of the ellipse. e = |cf|/a, where |cf| is the distance from the center to a focus (=h, assuming no tilt) and a is the semimajor axis
    e = 0.7
    a = 1.0    # a is the semi-major axis

    # Finding semi-minor axis, b given semi-major axis, a and eccentricity, e
    b = a*(1-e**2)**0.5

    # given a & e, you can find the focal distance c using e = c/a or c = ea
    c = e*a

    # given a & e and having calculated b, we can find horizontal offset, h, and vertical, k
    if b<a:
        k = 0
        h = (a**2-b**2)**0.5
    elif a<b:
        h = 0
        k = (b**2-a**2)**0.5
    else: # a==b
        h = k = 0

    datapoints = 12000 # number of points to use for drawing the ellipse
    datastepsize = TWOPI/datapoints
    playbackpoints = 3000
    #1200-151 # number of points to use when animating the planet
    playbackstepsize = TWOPI/playbackpoints

    # theta is the angle at the center of the ellipse from periapsis to a helper point, y, on the auxilliary circle
    theta = np.arange(0.0, TWOPI+datastepsize/2, datastepsize)

    # find the eccentric anomaly (angle) based on the mean anomaly
    def EA(M, n):
        EA = M
        for k in range(n):
            EA = EA + (M + e*np.sin(EA) - EA)*(1+e*np.cos(EA))/(1-e**2*(np.cos(EA))**2)
        return EA

    """ graveyard of failed formulas to find eccentric anomaly:
        theta = M + 2*e*sin(M) + (5/4)*e**2*sin(2*M) + e**3*((13/12)*sin(3*M)-(1/4)*sin(M)) # not sure why this doesn't work but ok, i'll step through M
        theta = np.zeros(datapoints, dtype=float)
        for i in M:
        #     theta[i] = M[i] + 2*e*sin(M[i]) + (5/4)*e**2*sin(2*M[i]) + e**3*((13/12)*sin(3*M[i])-(1/4)*sin(M[i]))
            print(f'step {i}: M[i]={M[i]} θ[i]={theta[i]}')
        with np.nditer(theta, op_flags=['readwrite']) as it:
            for m in it:
                m[...] = E(m, 1000)
               m[...] = m + m + (2*e-(1/4)*e**3)*np.sin(m)+((5/4)*e**2)*np.sin(2*m)+((13/12)*e**3)*np.sin(3*m)
                m[...] = m + 2*e*np.sin(m) + (5/4)*e**2*np.sin(2*m) + e**3*((13/12)*np.sin(3*m)-(1/4)*np.sin(m))
                m[...] = TWOPI*(1+2*e*np.cos(m)+(5/2)*e**2*np.cos(2*m)+e**3*((13/4)*np.cos(3*m)-(1/4)*np.cos(m)))
        M = np.arange(0.0, TWOPI, datastepsize) # M is Newton's Mean Anomoly, values from 0 to 2π in increments of datastepsize
            analytical solution from Tokis, A Solution of Kepler’s Equation, https://www.scirp.org/pdf/IJAA_2014123013365071.pdf
        E = M + (e**2-(1-(1-e)*(1+e*M**2/(1-e)**3)**0.5)**2)**0.5
        # given mean anomaly, return the eccentric anomaly, from http://pepijndevos.nl/2015/02/05/simulating-the-solar-system.html
        def solve_kepler(eccentricity, mean_anomaly):
            # for the approximate formulae in the present context, tol = 10e-6 degrees is sufficient
            tolerance = 10e-6
            # E0 = M + e sin M
            eccentric_anomaly = mean_anomaly + (eccentricity * np.sin(mean_anomaly))
            # and iterate the following equations with n = 0,1,2,... until |delta E| <= tol
            while True:
                ax.set_title('M={:.3} E={:.3} ∆E={:.3} e={:.3}'.format(mean_anomaly,eccentric_anomaly,delta_eccentric_anomaly,e),fontsize=12)
                # delta M = M - (En - e sin En)
                delta_mean_anomaly = mean_anomaly - (eccentric_anomaly - (eccentricity * math.sin(eccentric_anomaly)))
                # delta E = delta M / (1 - e cos En)
                delta_eccentric_anomaly = delta_mean_anomaly / (1 - (eccentricity * math.cos(eccentric_anomaly)))
                # En+1 = En + delta E
                eccentric_anomaly += delta_eccentric_anomaly
                 print('eccentric anomaly: {} ∆: {}'.format(eccentric_anomaly, delta_eccentric_anomaly))
                if abs(delta_eccentric_anomaly) <= tolerance:
                    return eccentric_anomaly

        E = solve_kepler(e, M)
        E = M + 2*e*np.sin(M) + (5/4)*e**2*np.sin(2*M) + e**3*((13/12)*np.sin(3*M)-(1/4)*np.sin(M))
        E = M+ (e**2-(1-(1-e)*(1+e*M**2/(1-e)**3)**0.5)**2)**0.5 # eqs. 40 & 41 from Tokis, A Solution of Kepler’s Equation
        .
        .
        .
        sigh...
    """
    # calculate x and y for a circle in cartesian coordinates:
    xcircle = np.cos(theta)
    ycircle = np.sin(theta)

    xellipse = xcircle       # ellipse x values from -1 to 1
    yellipse = (b/a)*ycircle # ellipse y values from -1 to 1

    ax.set_aspect('equal') # makes the circle look like a circle
    #     cir = plt.plot(xcircle, ycircle, 'k-', linewidth=0.1, label='auxiliary circle')
    #     ell = plt.plot(xellipse, yellipse, 'b-', linewidth=0.5, label='ellipse (e={:.3})'.format(e))
    ell = plt.plot(xellipse, yellipse, 'w-', linewidth=1)

    # quick experiment to find which coordinates to use for text
    # for i in range(10):
    #     ax.text(i/10, 1-i/10, 'left top at {}'.format(i/10),
    #         horizontalalignment='left',
    #         verticalalignment='top',
    #         transform=ax.transAxes)

    # 'a=semimajor axis'
#     ax.text(0.77, 0.35, 'a=semi-major axis',
#             horizontalalignment='left',
#             verticalalignment='top',
#             transform=ax.transAxes,
#             fontsize='small',
#            )

    # 'b=semiminor axis'
#     ax.text(0.77, 0.28, 'b=semi-minor axis',
#             horizontalalignment='left',
#             verticalalignment='top',
#             transform=ax.transAxes,
#             fontsize='small',
#            )

    # aLine,  = plt.plot((0,xcircle[0]), (0,ycircle[0]), 'k:', linewidth=0.5) # static line from center to periapsis
    #     xpLine, = plt.plot((xcircle[0],xellipse[0]), (ycircle[0],yellipse[0]), 'k:', linewidth=0.5) # line connecting point x with planet p
    #     pLine,  = plt.plot((h,xellipse[0]),(k,yellipse[0]), 'k-', linewidth=0.5) # line connecting the sun and planet
#     yLine,  = plt.plot((0,xcircle[0]), (0,ycircle[0]), 'w:', linewidth=0.5) # moves with yDot showing mean anomaly
#     bLine,  = plt.plot((0,0), (0,b*np.sin(np.pi/2)), 'w:', linewidth=0.5) # static (not animated)
    #     xDot,   = plt.plot([xcircle[0]], [ycircle[0]], 'r.', markersize=10) # helper of angle==ecc. anomaly along circle
    #     yDot,   = plt.plot([xcircle[0]], [ycircle[0]], 'g.', markersize=10) # helper of angle==mean anomaly along circle
    pDot,   = plt.plot([xellipse[0]], [yellipse[0]], '.', color='lightgreen', markersize=25, label='planet') # location of planet
    focus0  = plt.plot(-h, -k, 'w. ', markersize=2, label='empty focus') # location of the "empty" focus
    focus1  = plt.plot(h, k, 'y* ', markersize=20, label='star at focus') # plot the location of the star next (so it appears above the "empty" focus if they overlap)

    # make a polygon to show the area of the wedge described by focus1-periapsis-xDot
    #     xyPoly = [(h,0), (a,0)] # (x,y) starting point for the polygon located at periapsis
    #     xPoly = mpatches.Polygon(xyPoly, closed=True, edgecolor="black", facecolor='xkcd:light blue', alpha=0.1, label='area of x wedge =', animated=False)

    # and a wedge described by the center-periapsis-yDot
    #     yWedge = mpatches.Wedge(center=(0,0), r=1, theta1=0, theta2=0, edgecolor="black", facecolor='xkcd:very light purple', alpha=0.1, label='area of y wedge', animated=False)

    # Wedge and Polygon patches don't get added to the legend automatically so we'll have to do it
    handles, labels = ax.get_legend_handles_labels()
    #     handles.append(xPoly)
    #     handles.append(yWedge)
    plt.legend(bbox_to_anchor=(1.08, 1), # bbox_to_anchor lets you set the legend outside the figure
               handles=handles,          # our updated list of handles
               loc='upper right',
               ncol=1,
               fontsize='small',
               borderaxespad=0.0,
               shadow=True,
              )

    xy = (xcircle[0], ycircle[0]) # initial location of labels for xDot and yDot

    #     xDotAnnotation = ax.annotate('x',
    #                                  xy=xy,  xycoords='data',
    #                                  xytext=xy, textcoords='data',
    #                                  horizontalalignment='center', verticalalignment='center',
    #                                 )

    #     yDotAnnotation = ax.annotate('y',
    #                                  xy=xy,  xycoords='data',
    #                                  xytext=xy, textcoords='data',
    #                                  horizontalalignment='center', verticalalignment='center',
    #                                 )

#     yLineAnnotation = ax.annotate('a',
#                                  xy=xy,  xycoords='data',
#                                  xytext=(xy[0]/2,xy[1]/2), textcoords='data',
#                                  horizontalalignment='right', verticalalignment='top',
#                                 )

#     bLineAnnotation = ax.annotate('b',
#                                  xy=(0, 0),  xycoords='data',
#                                  xytext=(0, b*np.sin(np.pi/2)/2), textcoords='data',
#                                  horizontalalignment='right', verticalalignment='center',
#                                  )

    # Create the init function that returns the objects that will change during the animation process
    def init():
    #         ax.add_patch(xPoly)
    #         ax.add_patch(yWedge)
        return pDot
    #         return pDot, yDot, yDotAnnotation, yLine, yLineAnnotation, xDot, xDotAnnotation, xpLine, pLine, xPoly, yWedge

    """
    Note that the value at x[-1] yields the last value in the numpy ndarray x.

    It's the same value as x[floor(1000*TWOPI)], so when we want to reference various
    values of x and y based on the iterator i with values from 0 to 2π the index of the
    array x or y is the floor of 1000*i. It's times 1000 because we initially used a step
    size of 1/1000 or 0.001. In the general case, it would be x[floor(i/datastepsize)].
    """

    def animate(radians): # we are iterating over the circle twice, from 0 to 4π
        M = radians       # M is the mean anomaly
        E = EA(M,20)

        xx = xcircle[floor((E/datastepsize)%datapoints)] # x position for xdot
        yx = ycircle[floor((E/datastepsize)%datapoints)] # y position for xdot

    #         if (radians<TWOPI): # grow shapes on 1st pass
    #             xyPoly.append((xx, yx))
    #             yWedge.set_theta2(M*360/TWOPI)
    #         else:               # shrink shapes on 2nd pass
    #             del(xyPoly[1])  # delete the 2nd item in the list because deleting xyPoly[0] removes the focus
    #             yWedge.set_theta1(M*360/TWOPI)

        xy = xcircle[floor((M/datastepsize)%datapoints)] # x position for ydot
        yy = ycircle[floor((M/datastepsize)%datapoints)] # y position for ydot

        xp = xx
        yp = yx*b/a # find the location of the planet, pDot by dropping the location of xDot vertically onto the ellipse

    #         yDotAnnotation.set_position((xy*1.1, yy*1.1)) # set the annotation outside the circle
    #         yLine.set_data((0,xy), (0,yy))
    #         yLineAnnotation.set_position((xy/2, yy/2))
    #         yDot.set_data(xy, yy)
    #         xDotAnnotation.set_position((xx*1.1, yx*1.1))
    #         xpLine.set_data((xx,xp), (yx,yp))
    #         xDot.set_data(xx, yx)
        pDot.set_data(xp,yp)
    #         pLine.set_data((h,xp),(k,yp))
    #         xPoly.set_xy(xyPoly)

        return pDot
    #         return pDot, yDot, yDotAnnotation, yLine, yLineAnnotation, xDot, xDotAnnotation, xpLine, pLine, xPoly, yWedge

    progress_callback = lambda i, n: print(f'Saving frame {i+1} of {n}')
    animation = FuncAnimation(fig, animate, 
                              frames=np.arange(0.0, TWOPI, playbackstepsize), # run the animation once around the circle
                              interval=1, blit=False, repeat=False, init_func=init)

    writer = FFMpegWriter(fps=15, metadata=dict(artist='Stephen Shadle'), bitrate=1800)
    animation.save("kepler's 1st law minimal.{:^2.2f}.{}.mp4".format(e,playbackpoints), writer=writer, 
                   progress_callback=progress_callback
                 ) #current directoryanimate
# Out:
# <img src="data:image/png;base64,..." width="670">
# Saving frame 1 of 3001
# Saving frame 2 of 3001
# Saving frame 3 of 3001
# Saving frame 4 of 3001
# Saving frame 5 of 3001
# Saving frame 6 of 3001
# Saving frame 7 of 3001
# Saving frame 8 of 3001
# Saving frame 9 of 3001
# Saving frame 10 of 3001
# Saving frame 11 of 3001
# Saving frame 12 of 3001
# Saving frame 13 of 3001
# Saving frame 14 of 3001
# Saving frame 15 of 3001
# Saving frame 16 of 3001
# Saving frame 17 of 3001
# Saving frame 18 of 3001
# Saving frame 19 of 3001
# Saving frame 20 of 3001
# Saving frame 21 of 3001
# Saving frame 22 of 3001
# Saving frame 23 of 3001
# Saving frame 24 of 3001
# Saving frame 25 of 3001
# Saving frame 26 of 3001
# Saving frame 27 of 3001
# Saving frame 28 of 3001
# Saving frame 29 of 3001
# Saving frame 30 of 3001
# Saving frame 31 of 3001
# Saving frame 32 of 3001
# Saving frame 33 of 3001
# Saving frame 34 of 3001
# Saving frame 35 of 3001
# Saving frame 36 of 3001
# Saving frame 37 of 3001
# Saving frame 38 of 3001
# Saving frame 39 of 3001
# Saving frame 40 of 3001
# Saving frame 41 of 3001
# Saving frame 42 of 3001
# Saving frame 43 of 3001
# Saving frame 44 of 3001
# Saving frame 45 of 3001
# Saving frame 46 of 3001
# Saving frame 47 of 3001
# Saving frame 48 of 3001
# Saving frame 49 of 3001
# Saving frame 50 of 3001
# Saving frame 51 of 3001
# Saving frame 52 of 3001
# Saving frame 53 of 3001
# Saving frame 54 of 3001
# Saving frame 55 of 3001
# Saving frame 56 of 3001
# Saving frame 57 of 3001
# Saving frame 58 of 3001
# Saving frame 59 of 3001
# Saving frame 60 of 3001
# Saving frame 61 of 3001
# Saving frame 62 of 3001
# Saving frame 63 of 3001
# Saving frame 64 of 3001
# Saving frame 65 of 3001
# Saving frame 66 of 3001
# Saving frame 67 of 3001
# Saving frame 68 of 3001
# Saving frame 69 of 3001
# Saving frame 70 of 3001
# Saving frame 71 of 3001
# Saving frame 72 of 3001
# Saving frame 73 of 3001
# Saving frame 74 of 3001
# Saving frame 75 of 3001
# Saving frame 76 of 3001
# Saving frame 77 of 3001
# Saving frame 78 of 3001
# Saving frame 79 of 3001
# Saving frame 80 of 3001
# Saving frame 81 of 3001
# Saving frame 82 of 3001
# Saving frame 83 of 3001
# Saving frame 84 of 3001
# Saving frame 85 of 3001
# Saving frame 86 of 3001
# Saving frame 87 of 3001
# Saving frame 88 of 3001
# Saving frame 89 of 3001
# Saving frame 90 of 3001
# Saving frame 91 of 3001
# Saving frame 92 of 3001
# Saving frame 93 of 3001
# Saving frame 94 of 3001
# Saving frame 95 of 3001
# Saving frame 96 of 3001
# Saving frame 97 of 3001
# Saving frame 98 of 3001
# Saving frame 99 of 3001
# Saving frame 100 of 3001
# Saving frame 101 of 3001
# Saving frame 102 of 3001
# Saving frame 103 of 3001
# Saving frame 104 of 3001
# Saving frame 105 of 3001
# Saving frame 106 of 3001
# Saving frame 107 of 3001
# Saving frame 108 of 3001
# Saving frame 109 of 3001
# Saving frame 110 of 3001
# Saving frame 111 of 3001
# Saving frame 112 of 3001
# Saving frame 113 of 3001
# Saving frame 114 of 3001
# Saving frame 115 of 3001
# Saving frame 116 of 3001
# Saving frame 117 of 3001
# Saving frame 118 of 3001
# Saving frame 119 of 3001
# Saving frame 120 of 3001
# Saving frame 121 of 3001
# Saving frame 122 of 3001
# Saving frame 123 of 3001
# Saving frame 124 of 3001
# Saving frame 125 of 3001
# Saving frame 126 of 3001
# Saving frame 127 of 3001
# Saving frame 128 of 3001
# Saving frame 129 of 3001
# Saving frame 130 of 3001
# Saving frame 131 of 3001
# Saving frame 132 of 3001
# Saving frame 133 of 3001
# Saving frame 134 of 3001
# Saving frame 135 of 3001
# Saving frame 136 of 3001
# Saving frame 137 of 3001
# Saving frame 138 of 3001
# Saving frame 139 of 3001
# Saving frame 140 of 3001
# Saving frame 141 of 3001
# Saving frame 142 of 3001
# Saving frame 143 of 3001
# Saving frame 144 of 3001
# Saving frame 145 of 3001
# Saving frame 146 of 3001
# Saving frame 147 of 3001
# Saving frame 148 of 3001
# Saving frame 149 of 3001
# Saving frame 150 of 3001
# Saving frame 151 of 3001
# Saving frame 152 of 3001
# Saving frame 153 of 3001
# Saving frame 154 of 3001
# Saving frame 155 of 3001
# Saving frame 156 of 3001
# Saving frame 157 of 3001
# Saving frame 158 of 3001
# Saving frame 159 of 3001
# Saving frame 160 of 3001
# Saving frame 161 of 3001
# Saving frame 162 of 3001
# Saving frame 163 of 3001
# Saving frame 164 of 3001
# Saving frame 165 of 3001
# Saving frame 166 of 3001
# Saving frame 167 of 3001
# Saving frame 168 of 3001
# Saving frame 169 of 3001
# Saving frame 170 of 3001
# Saving frame 171 of 3001
# Saving frame 172 of 3001
# Saving frame 173 of 3001
# Saving frame 174 of 3001
# Saving frame 175 of 3001
# Saving frame 176 of 3001
# Saving frame 177 of 3001
# Saving frame 178 of 3001
# Saving frame 179 of 3001
# Saving frame 180 of 3001
# Saving frame 181 of 3001
# Saving frame 182 of 3001
# Saving frame 183 of 3001
# Saving frame 184 of 3001
# Saving frame 185 of 3001
# Saving frame 186 of 3001
# Saving frame 187 of 3001
# Saving frame 188 of 3001
# Saving frame 189 of 3001
# Saving frame 190 of 3001
# Saving frame 191 of 3001
# Saving frame 192 of 3001
# Saving frame 193 of 3001
# Saving frame 194 of 3001
# Saving frame 195 of 3001
# Saving frame 196 of 3001
# Saving frame 197 of 3001
# Saving frame 198 of 3001
# Saving frame 199 of 3001
# Saving frame 200 of 3001
# Saving frame 201 of 3001
# Saving frame 202 of 3001
# Saving frame 203 of 3001
# Saving frame 204 of 3001
# Saving frame 205 of 3001
# Saving frame 206 of 3001
# Saving frame 207 of 3001
# Saving frame 208 of 3001
# Saving frame 209 of 3001
# Saving frame 210 of 3001
# Saving frame 211 of 3001
# Saving frame 212 of 3001
# Saving frame 213 of 3001
# Saving frame 214 of 3001
# Saving frame 215 of 3001
# Saving frame 216 of 3001
# Saving frame 217 of 3001
# Saving frame 218 of 3001
# Saving frame 219 of 3001
# Saving frame 220 of 3001
# Saving frame 221 of 3001
# Saving frame 222 of 3001
# Saving frame 223 of 3001
# Saving frame 224 of 3001
# Saving frame 225 of 3001
# Saving frame 226 of 3001
# Saving frame 227 of 3001
# Saving frame 228 of 3001
# Saving frame 229 of 3001
# Saving frame 230 of 3001
# Saving frame 231 of 3001
# Saving frame 232 of 3001
# Saving frame 233 of 3001
# Saving frame 234 of 3001
# Saving frame 235 of 3001
# Saving frame 236 of 3001
# Saving frame 237 of 3001
# Saving frame 238 of 3001
# Saving frame 239 of 3001
# Saving frame 240 of 3001
# Saving frame 241 of 3001
# Saving frame 242 of 3001
# Saving frame 243 of 3001
# Saving frame 244 of 3001
# Saving frame 245 of 3001
# Saving frame 246 of 3001
# Saving frame 247 of 3001
# Saving frame 248 of 3001
# Saving frame 249 of 3001
# Saving frame 250 of 3001
# Saving frame 251 of 3001
# Saving frame 252 of 3001
# Saving frame 253 of 3001
# Saving frame 254 of 3001
# Saving frame 255 of 3001
# Saving frame 256 of 3001
# Saving frame 257 of 3001
# Saving frame 258 of 3001
# Saving frame 259 of 3001
# Saving frame 260 of 3001
# Saving frame 261 of 3001
# Saving frame 262 of 3001
# Saving frame 263 of 3001
# Saving frame 264 of 3001
# Saving frame 265 of 3001
# Saving frame 266 of 3001
# Saving frame 267 of 3001
# Saving frame 268 of 3001
# Saving frame 269 of 3001
# Saving frame 270 of 3001
# Saving frame 271 of 3001
# Saving frame 272 of 3001
# Saving frame 273 of 3001
# Saving frame 274 of 3001
# Saving frame 275 of 3001
# Saving frame 276 of 3001
# Saving frame 277 of 3001
# Saving frame 278 of 3001
# Saving frame 279 of 3001
# Saving frame 280 of 3001
# Saving frame 281 of 3001
# Saving frame 282 of 3001
# Saving frame 283 of 3001
# Saving frame 284 of 3001
# Saving frame 285 of 3001
# Saving frame 286 of 3001
# Saving frame 287 of 3001
# Saving frame 288 of 3001
# Saving frame 289 of 3001
# Saving frame 290 of 3001
# Saving frame 291 of 3001
# Saving frame 292 of 3001
# Saving frame 293 of 3001
# Saving frame 294 of 3001
# Saving frame 295 of 3001
# Saving frame 296 of 3001
# Saving frame 297 of 3001
# Saving frame 298 of 3001
# Saving frame 299 of 3001
# Saving frame 300 of 3001
# Saving frame 301 of 3001
# Saving frame 302 of 3001
# Saving frame 303 of 3001
# Saving frame 304 of 3001
# Saving frame 305 of 3001
# Saving frame 306 of 3001
# Saving frame 307 of 3001
# Saving frame 308 of 3001
# Saving frame 309 of 3001
# Saving frame 310 of 3001
# Saving frame 311 of 3001
# Saving frame 312 of 3001
# Saving frame 313 of 3001
# Saving frame 314 of 3001
# Saving frame 315 of 3001
# Saving frame 316 of 3001
# Saving frame 317 of 3001
# Saving frame 318 of 3001
# Saving frame 319 of 3001
# Saving frame 320 of 3001
# Saving frame 321 of 3001
# Saving frame 322 of 3001
# Saving frame 323 of 3001
# Saving frame 324 of 3001
# Saving frame 325 of 3001
# Saving frame 326 of 3001
# Saving frame 327 of 3001
# Saving frame 328 of 3001
# Saving frame 329 of 3001
# Saving frame 330 of 3001
# Saving frame 331 of 3001
# Saving frame 332 of 3001
# Saving frame 333 of 3001
# Saving frame 334 of 3001
# Saving frame 335 of 3001
# Saving frame 336 of 3001
# Saving frame 337 of 3001
# Saving frame 338 of 3001
# Saving frame 339 of 3001
# Saving frame 340 of 3001
# Saving frame 341 of 3001
# Saving frame 342 of 3001
# Saving frame 343 of 3001
# Saving frame 344 of 3001
# Saving frame 345 of 3001
# Saving frame 346 of 3001
# Saving frame 347 of 3001
# Saving frame 348 of 3001
# Saving frame 349 of 3001
# Saving frame 350 of 3001
# Saving frame 351 of 3001
# Saving frame 352 of 3001
# Saving frame 353 of 3001
# Saving frame 354 of 3001
# Saving frame 355 of 3001
# Saving frame 356 of 3001
# Saving frame 357 of 3001
# Saving frame 358 of 3001
# Saving frame 359 of 3001
# Saving frame 360 of 3001
# Saving frame 361 of 3001
# Saving frame 362 of 3001
# Saving frame 363 of 3001
# Saving frame 364 of 3001
# Saving frame 365 of 3001
# Saving frame 366 of 3001
# Saving frame 367 of 3001
# Saving frame 368 of 3001
# Saving frame 369 of 3001
# Saving frame 370 of 3001
# Saving frame 371 of 3001
# Saving frame 372 of 3001
# Saving frame 373 of 3001
# Saving frame 374 of 3001
# Saving frame 375 of 3001
# Saving frame 376 of 3001
# Saving frame 377 of 3001
# Saving frame 378 of 3001
# Saving frame 379 of 3001
# Saving frame 380 of 3001
# Saving frame 381 of 3001
# Saving frame 382 of 3001
# Saving frame 383 of 3001
# Saving frame 384 of 3001
# Saving frame 385 of 3001
# Saving frame 386 of 3001
# Saving frame 387 of 3001
# Saving frame 388 of 3001
# Saving frame 389 of 3001
# Saving frame 390 of 3001
# Saving frame 391 of 3001
# Saving frame 392 of 3001
# Saving frame 393 of 3001
# Saving frame 394 of 3001
# Saving frame 395 of 3001
# Saving frame 396 of 3001
# Saving frame 397 of 3001
# Saving frame 398 of 3001
# Saving frame 399 of 3001
# Saving frame 400 of 3001
# Saving frame 401 of 3001
# Saving frame 402 of 3001
# Saving frame 403 of 3001
# Saving frame 404 of 3001
# Saving frame 405 of 3001
# Saving frame 406 of 3001
# Saving frame 407 of 3001
# Saving frame 408 of 3001
# Saving frame 409 of 3001
# Saving frame 410 of 3001
# Saving frame 411 of 3001
# Saving frame 412 of 3001
# Saving frame 413 of 3001
# Saving frame 414 of 3001
# Saving frame 415 of 3001
# Saving frame 416 of 3001
# Saving frame 417 of 3001
# Saving frame 418 of 3001
# Saving frame 419 of 3001
# Saving frame 420 of 3001
# Saving frame 421 of 3001
# Saving frame 422 of 3001
# Saving frame 423 of 3001
# Saving frame 424 of 3001
# Saving frame 425 of 3001
# Saving frame 426 of 3001
# Saving frame 427 of 3001
# Saving frame 428 of 3001
# Saving frame 429 of 3001
# Saving frame 430 of 3001
# Saving frame 431 of 3001
# Saving frame 432 of 3001
# Saving frame 433 of 3001
# Saving frame 434 of 3001
# Saving frame 435 of 3001
# Saving frame 436 of 3001
# Saving frame 437 of 3001
# Saving frame 438 of 3001
# Saving frame 439 of 3001
# Saving frame 440 of 3001
# Saving frame 441 of 3001
# Saving frame 442 of 3001
# Saving frame 443 of 3001
# Saving frame 444 of 3001
# Saving frame 445 of 3001
# Saving frame 446 of 3001
# Saving frame 447 of 3001
# Saving frame 448 of 3001
# Saving frame 449 of 3001
# Saving frame 450 of 3001
# Saving frame 451 of 3001
# Saving frame 452 of 3001
# Saving frame 453 of 3001
# Saving frame 454 of 3001
# Saving frame 455 of 3001
# Saving frame 456 of 3001
# Saving frame 457 of 3001
# Saving frame 458 of 3001
# Saving frame 459 of 3001
# Saving frame 460 of 3001
# Saving frame 461 of 3001
# Saving frame 462 of 3001
# Saving frame 463 of 3001
# Saving frame 464 of 3001
# Saving frame 465 of 3001
# Saving frame 466 of 3001
# Saving frame 467 of 3001
# Saving frame 468 of 3001
# Saving frame 469 of 3001
# Saving frame 470 of 3001
# Saving frame 471 of 3001
# Saving frame 472 of 3001
# Saving frame 473 of 3001
# Saving frame 474 of 3001
# Saving frame 475 of 3001
# Saving frame 476 of 3001
# Saving frame 477 of 3001
# Saving frame 478 of 3001
# Saving frame 479 of 3001
# Saving frame 480 of 3001
# Saving frame 481 of 3001
# Saving frame 482 of 3001
# Saving frame 483 of 3001
# Saving frame 484 of 3001
# Saving frame 485 of 3001
# Saving frame 486 of 3001
# Saving frame 487 of 3001
# Saving frame 488 of 3001
# Saving frame 489 of 3001
# Saving frame 490 of 3001
# Saving frame 491 of 3001
# Saving frame 492 of 3001
# Saving frame 493 of 3001
# Saving frame 494 of 3001
# Saving frame 495 of 3001
# Saving frame 496 of 3001
# Saving frame 497 of 3001
# Saving frame 498 of 3001
# Saving frame 499 of 3001
# Saving frame 500 of 3001
# Saving frame 501 of 3001
# Saving frame 502 of 3001
# Saving frame 503 of 3001
# Saving frame 504 of 3001
# Saving frame 505 of 3001
# Saving frame 506 of 3001
# Saving frame 507 of 3001
# Saving frame 508 of 3001
# Saving frame 509 of 3001
# Saving frame 510 of 3001
# Saving frame 511 of 3001
# Saving frame 512 of 3001
# Saving frame 513 of 3001
# Saving frame 514 of 3001
# Saving frame 515 of 3001
# Saving frame 516 of 3001
# Saving frame 517 of 3001
# Saving frame 518 of 3001
# Saving frame 519 of 3001
# Saving frame 520 of 3001
# Saving frame 521 of 3001
# Saving frame 522 of 3001
# Saving frame 523 of 3001
# Saving frame 524 of 3001
# Saving frame 525 of 3001
# Saving frame 526 of 3001
# Saving frame 527 of 3001
# Saving frame 528 of 3001
# Saving frame 529 of 3001
# Saving frame 530 of 3001
# Saving frame 531 of 3001
# Saving frame 532 of 3001
# Saving frame 533 of 3001
# Saving frame 534 of 3001
# Saving frame 535 of 3001
# Saving frame 536 of 3001
# Saving frame 537 of 3001
# Saving frame 538 of 3001
# Saving frame 539 of 3001
# Saving frame 540 of 3001
# Saving frame 541 of 3001
# Saving frame 542 of 3001
# Saving frame 543 of 3001
# Saving frame 544 of 3001
# Saving frame 545 of 3001
# Saving frame 546 of 3001
# Saving frame 547 of 3001
# Saving frame 548 of 3001
# Saving frame 549 of 3001
# Saving frame 550 of 3001
# Saving frame 551 of 3001
# Saving frame 552 of 3001
# Saving frame 553 of 3001
# Saving frame 554 of 3001
# Saving frame 555 of 3001
# Saving frame 556 of 3001
# Saving frame 557 of 3001
# Saving frame 558 of 3001
# Saving frame 559 of 3001
# Saving frame 560 of 3001
# Saving frame 561 of 3001
# Saving frame 562 of 3001
# Saving frame 563 of 3001
# Saving frame 564 of 3001
# Saving frame 565 of 3001
# Saving frame 566 of 3001
# Saving frame 567 of 3001
# Saving frame 568 of 3001
# Saving frame 569 of 3001
# Saving frame 570 of 3001
# Saving frame 571 of 3001
# Saving frame 572 of 3001
# Saving frame 573 of 3001
# Saving frame 574 of 3001
# Saving frame 575 of 3001
# Saving frame 576 of 3001
# Saving frame 577 of 3001
# Saving frame 578 of 3001
# Saving frame 579 of 3001
# Saving frame 580 of 3001
# Saving frame 581 of 3001
# Saving frame 582 of 3001
# Saving frame 583 of 3001
# Saving frame 584 of 3001
# Saving frame 585 of 3001
# Saving frame 586 of 3001
# Saving frame 587 of 3001
# Saving frame 588 of 3001
# Saving frame 589 of 3001
# Saving frame 590 of 3001
# Saving frame 591 of 3001
# Saving frame 592 of 3001
# Saving frame 593 of 3001
# Saving frame 594 of 3001
# Saving frame 595 of 3001
# Saving frame 596 of 3001
# Saving frame 597 of 3001
# Saving frame 598 of 3001
# Saving frame 599 of 3001
# Saving frame 600 of 3001
# Saving frame 601 of 3001
# Saving frame 602 of 3001
# Saving frame 603 of 3001
# Saving frame 604 of 3001
# Saving frame 605 of 3001
# Saving frame 606 of 3001
# Saving frame 607 of 3001
# Saving frame 608 of 3001
# Saving frame 609 of 3001
# Saving frame 610 of 3001
# Saving frame 611 of 3001
# Saving frame 612 of 3001
# Saving frame 613 of 3001
# Saving frame 614 of 3001
# Saving frame 615 of 3001
# Saving frame 616 of 3001
# Saving frame 617 of 3001
# Saving frame 618 of 3001
# Saving frame 619 of 3001
# Saving frame 620 of 3001
# Saving frame 621 of 3001
# Saving frame 622 of 3001
# Saving frame 623 of 3001
# Saving frame 624 of 3001
# Saving frame 625 of 3001
# Saving frame 626 of 3001
# Saving frame 627 of 3001
# Saving frame 628 of 3001
# Saving frame 629 of 3001
# Saving frame 630 of 3001
# Saving frame 631 of 3001
# Saving frame 632 of 3001
# Saving frame 633 of 3001
# Saving frame 634 of 3001
# Saving frame 635 of 3001
# Saving frame 636 of 3001
# Saving frame 637 of 3001
# Saving frame 638 of 3001
# Saving frame 639 of 3001
# Saving frame 640 of 3001
# Saving frame 641 of 3001
# Saving frame 642 of 3001
# Saving frame 643 of 3001
# Saving frame 644 of 3001
# Saving frame 645 of 3001
# Saving frame 646 of 3001
# Saving frame 647 of 3001
# Saving frame 648 of 3001
# Saving frame 649 of 3001
# Saving frame 650 of 3001
# Saving frame 651 of 3001
# Saving frame 652 of 3001
# Saving frame 653 of 3001
# Saving frame 654 of 3001
# Saving frame 655 of 3001
# Saving frame 656 of 3001
# Saving frame 657 of 3001
# Saving frame 658 of 3001
# Saving frame 659 of 3001
# Saving frame 660 of 3001
# Saving frame 661 of 3001
# Saving frame 662 of 3001
# Saving frame 663 of 3001
# Saving frame 664 of 3001
# Saving frame 665 of 3001
# Saving frame 666 of 3001
# Saving frame 667 of 3001
# Saving frame 668 of 3001
# Saving frame 669 of 3001
# Saving frame 670 of 3001
# Saving frame 671 of 3001
# Saving frame 672 of 3001
# Saving frame 673 of 3001
# Saving frame 674 of 3001
# Saving frame 675 of 3001
# Saving frame 676 of 3001
# Saving frame 677 of 3001
# Saving frame 678 of 3001
# Saving frame 679 of 3001
# Saving frame 680 of 3001
# Saving frame 681 of 3001
# Saving frame 682 of 3001
# Saving frame 683 of 3001
# Saving frame 684 of 3001
# Saving frame 685 of 3001
# Saving frame 686 of 3001
# Saving frame 687 of 3001
# Saving frame 688 of 3001
# Saving frame 689 of 3001
# Saving frame 690 of 3001
# Saving frame 691 of 3001
# Saving frame 692 of 3001
# Saving frame 693 of 3001
# Saving frame 694 of 3001
# Saving frame 695 of 3001
# Saving frame 696 of 3001
# Saving frame 697 of 3001
# Saving frame 698 of 3001
# Saving frame 699 of 3001
# Saving frame 700 of 3001
# Saving frame 701 of 3001
# Saving frame 702 of 3001
# Saving frame 703 of 3001
# Saving frame 704 of 3001
# Saving frame 705 of 3001
# Saving frame 706 of 3001
# Saving frame 707 of 3001
# Saving frame 708 of 3001
# Saving frame 709 of 3001
# Saving frame 710 of 3001
# Saving frame 711 of 3001
# Saving frame 712 of 3001
# Saving frame 713 of 3001
# Saving frame 714 of 3001
# Saving frame 715 of 3001
# Saving frame 716 of 3001
# Saving frame 717 of 3001
# Saving frame 718 of 3001
# Saving frame 719 of 3001
# Saving frame 720 of 3001
# Saving frame 721 of 3001
# Saving frame 722 of 3001
# Saving frame 723 of 3001
# Saving frame 724 of 3001
# Saving frame 725 of 3001
# Saving frame 726 of 3001
# Saving frame 727 of 3001
# Saving frame 728 of 3001
# Saving frame 729 of 3001
# Saving frame 730 of 3001
# Saving frame 731 of 3001
# Saving frame 732 of 3001
# Saving frame 733 of 3001
# Saving frame 734 of 3001
# Saving frame 735 of 3001
# Saving frame 736 of 3001
# Saving frame 737 of 3001
# Saving frame 738 of 3001
# Saving frame 739 of 3001
# Saving frame 740 of 3001
# Saving frame 741 of 3001
# Saving frame 742 of 3001
# Saving frame 743 of 3001
# Saving frame 744 of 3001
# Saving frame 745 of 3001
# Saving frame 746 of 3001
# Saving frame 747 of 3001
# Saving frame 748 of 3001
# Saving frame 749 of 3001
# Saving frame 750 of 3001
# Saving frame 751 of 3001
# Saving frame 752 of 3001
# Saving frame 753 of 3001
# Saving frame 754 of 3001
# Saving frame 755 of 3001
# Saving frame 756 of 3001
# Saving frame 757 of 3001
# Saving frame 758 of 3001
# Saving frame 759 of 3001
# Saving frame 760 of 3001
# Saving frame 761 of 3001
# Saving frame 762 of 3001
# Saving frame 763 of 3001
# Saving frame 764 of 3001
# Saving frame 765 of 3001
# Saving frame 766 of 3001
# Saving frame 767 of 3001
# Saving frame 768 of 3001
# Saving frame 769 of 3001
# Saving frame 770 of 3001
# Saving frame 771 of 3001
# Saving frame 772 of 3001
# Saving frame 773 of 3001
# Saving frame 774 of 3001
# Saving frame 775 of 3001
# Saving frame 776 of 3001
# Saving frame 777 of 3001
# Saving frame 778 of 3001
# Saving frame 779 of 3001
# Saving frame 780 of 3001
# Saving frame 781 of 3001
# Saving frame 782 of 3001
# Saving frame 783 of 3001
# Saving frame 784 of 3001
# Saving frame 785 of 3001
# Saving frame 786 of 3001
# Saving frame 787 of 3001
# Saving frame 788 of 3001
# Saving frame 789 of 3001
# Saving frame 790 of 3001
# Saving frame 791 of 3001
# Saving frame 792 of 3001
# Saving frame 793 of 3001
# Saving frame 794 of 3001
# Saving frame 795 of 3001
# Saving frame 796 of 3001
# Saving frame 797 of 3001
# Saving frame 798 of 3001
# Saving frame 799 of 3001
# Saving frame 800 of 3001
# Saving frame 801 of 3001
# Saving frame 802 of 3001
# Saving frame 803 of 3001
# Saving frame 804 of 3001
# Saving frame 805 of 3001
# Saving frame 806 of 3001
# Saving frame 807 of 3001
# Saving frame 808 of 3001
# Saving frame 809 of 3001
# Saving frame 810 of 3001
# Saving frame 811 of 3001
# Saving frame 812 of 3001
# Saving frame 813 of 3001
# Saving frame 814 of 3001
# Saving frame 815 of 3001
# Saving frame 816 of 3001
# Saving frame 817 of 3001
# Saving frame 818 of 3001
# Saving frame 819 of 3001
# Saving frame 820 of 3001
# Saving frame 821 of 3001
# Saving frame 822 of 3001
# Saving frame 823 of 3001
# Saving frame 824 of 3001
# Saving frame 825 of 3001
# Saving frame 826 of 3001
# Saving frame 827 of 3001
# Saving frame 828 of 3001
# Saving frame 829 of 3001
# Saving frame 830 of 3001
# Saving frame 831 of 3001
# Saving frame 832 of 3001
# Saving frame 833 of 3001
# Saving frame 834 of 3001
# Saving frame 835 of 3001
# Saving frame 836 of 3001
# Saving frame 837 of 3001
# Saving frame 838 of 3001
# Saving frame 839 of 3001
# Saving frame 840 of 3001
# Saving frame 841 of 3001
# Saving frame 842 of 3001
# Saving frame 843 of 3001
# Saving frame 844 of 3001
# Saving frame 845 of 3001
# Saving frame 846 of 3001
# Saving frame 847 of 3001
# Saving frame 848 of 3001
# Saving frame 849 of 3001
# Saving frame 850 of 3001
# Saving frame 851 of 3001
# Saving frame 852 of 3001
# Saving frame 853 of 3001
# Saving frame 854 of 3001
# Saving frame 855 of 3001
# Saving frame 856 of 3001
# Saving frame 857 of 3001
# Saving frame 858 of 3001
# Saving frame 859 of 3001
# Saving frame 860 of 3001
# Saving frame 861 of 3001
# Saving frame 862 of 3001
# Saving frame 863 of 3001
# Saving frame 864 of 3001
# Saving frame 865 of 3001
# Saving frame 866 of 3001
# Saving frame 867 of 3001
# Saving frame 868 of 3001
# Saving frame 869 of 3001
# Saving frame 870 of 3001
# Saving frame 871 of 3001
# Saving frame 872 of 3001
# Saving frame 873 of 3001
# Saving frame 874 of 3001
# Saving frame 875 of 3001
# Saving frame 876 of 3001
# Saving frame 877 of 3001
# Saving frame 878 of 3001
# Saving frame 879 of 3001
# Saving frame 880 of 3001
# Saving frame 881 of 3001
# Saving frame 882 of 3001
# Saving frame 883 of 3001
# Saving frame 884 of 3001
# Saving frame 885 of 3001
# Saving frame 886 of 3001
# Saving frame 887 of 3001
# Saving frame 888 of 3001
# Saving frame 889 of 3001
# Saving frame 890 of 3001
# Saving frame 891 of 3001
# Saving frame 892 of 3001
# Saving frame 893 of 3001
# Saving frame 894 of 3001
# Saving frame 895 of 3001
# Saving frame 896 of 3001
# Saving frame 897 of 3001
# Saving frame 898 of 3001
# Saving frame 899 of 3001
# Saving frame 900 of 3001
# Saving frame 901 of 3001
# Saving frame 902 of 3001
# Saving frame 903 of 3001
# Saving frame 904 of 3001
# Saving frame 905 of 3001
# Saving frame 906 of 3001
# Saving frame 907 of 3001
# Saving frame 908 of 3001
# Saving frame 909 of 3001
# Saving frame 910 of 3001
# Saving frame 911 of 3001
# Saving frame 912 of 3001
# Saving frame 913 of 3001
# Saving frame 914 of 3001
# Saving frame 915 of 3001
# Saving frame 916 of 3001
# Saving frame 917 of 3001
# Saving frame 918 of 3001
# Saving frame 919 of 3001
# Saving frame 920 of 3001
# Saving frame 921 of 3001
# Saving frame 922 of 3001
# Saving frame 923 of 3001
# Saving frame 924 of 3001
# Saving frame 925 of 3001
# Saving frame 926 of 3001
# Saving frame 927 of 3001
# Saving frame 928 of 3001
# Saving frame 929 of 3001
# Saving frame 930 of 3001
# Saving frame 931 of 3001
# Saving frame 932 of 3001
# Saving frame 933 of 3001
# Saving frame 934 of 3001
# Saving frame 935 of 3001
# Saving frame 936 of 3001
# Saving frame 937 of 3001
# Saving frame 938 of 3001
# Saving frame 939 of 3001
# Saving frame 940 of 3001
# Saving frame 941 of 3001
# Saving frame 942 of 3001
# Saving frame 943 of 3001
# Saving frame 944 of 3001
# Saving frame 945 of 3001
# Saving frame 946 of 3001
# Saving frame 947 of 3001
# Saving frame 948 of 3001
# Saving frame 949 of 3001
# Saving frame 950 of 3001
# Saving frame 951 of 3001
# Saving frame 952 of 3001
# Saving frame 953 of 3001
# Saving frame 954 of 3001
# Saving frame 955 of 3001
# Saving frame 956 of 3001
# Saving frame 957 of 3001
# Saving frame 958 of 3001
# Saving frame 959 of 3001
# Saving frame 960 of 3001
# Saving frame 961 of 3001
# Saving frame 962 of 3001
# Saving frame 963 of 3001
# Saving frame 964 of 3001
# Saving frame 965 of 3001
# Saving frame 966 of 3001
# Saving frame 967 of 3001
# Saving frame 968 of 3001
# Saving frame 969 of 3001
# Saving frame 970 of 3001
# Saving frame 971 of 3001
# Saving frame 972 of 3001
# Saving frame 973 of 3001
# Saving frame 974 of 3001
# Saving frame 975 of 3001
# Saving frame 976 of 3001
# Saving frame 977 of 3001
# Saving frame 978 of 3001
# Saving frame 979 of 3001
# Saving frame 980 of 3001
# Saving frame 981 of 3001
# Saving frame 982 of 3001
# Saving frame 983 of 3001
# Saving frame 984 of 3001
# Saving frame 985 of 3001
# Saving frame 986 of 3001
# Saving frame 987 of 3001
# Saving frame 988 of 3001
# Saving frame 989 of 3001
# Saving frame 990 of 3001
# Saving frame 991 of 3001
# Saving frame 992 of 3001
# Saving frame 993 of 3001
# Saving frame 994 of 3001
# Saving frame 995 of 3001
# Saving frame 996 of 3001
# Saving frame 997 of 3001
# Saving frame 998 of 3001
# Saving frame 999 of 3001
# Saving frame 1000 of 3001
# Saving frame 1001 of 3001
# Saving frame 1002 of 3001
# Saving frame 1003 of 3001
# Saving frame 1004 of 3001
# Saving frame 1005 of 3001
# Saving frame 1006 of 3001
# Saving frame 1007 of 3001
# Saving frame 1008 of 3001
# Saving frame 1009 of 3001
# Saving frame 1010 of 3001
# Saving frame 1011 of 3001
# Saving frame 1012 of 3001
# Saving frame 1013 of 3001
# Saving frame 1014 of 3001
# Saving frame 1015 of 3001
# Saving frame 1016 of 3001
# Saving frame 1017 of 3001
# Saving frame 1018 of 3001
# Saving frame 1019 of 3001
# Saving frame 1020 of 3001
# Saving frame 1021 of 3001
# Saving frame 1022 of 3001
# Saving frame 1023 of 3001
# Saving frame 1024 of 3001
# Saving frame 1025 of 3001
# Saving frame 1026 of 3001
# Saving frame 1027 of 3001
# Saving frame 1028 of 3001
# Saving frame 1029 of 3001
# Saving frame 1030 of 3001
# Saving frame 1031 of 3001
# Saving frame 1032 of 3001
# Saving frame 1033 of 3001
# Saving frame 1034 of 3001
# Saving frame 1035 of 3001
# Saving frame 1036 of 3001
# Saving frame 1037 of 3001
# Saving frame 1038 of 3001
# Saving frame 1039 of 3001
# Saving frame 1040 of 3001
# Saving frame 1041 of 3001
# Saving frame 1042 of 3001
# Saving frame 1043 of 3001
# Saving frame 1044 of 3001
# Saving frame 1045 of 3001
# Saving frame 1046 of 3001
# Saving frame 1047 of 3001
# Saving frame 1048 of 3001
# Saving frame 1049 of 3001
# Saving frame 1050 of 3001
# Saving frame 1051 of 3001
# Saving frame 1052 of 3001
# Saving frame 1053 of 3001
# Saving frame 1054 of 3001
# Saving frame 1055 of 3001
# Saving frame 1056 of 3001
# Saving frame 1057 of 3001
# Saving frame 1058 of 3001
# Saving frame 1059 of 3001
# Saving frame 1060 of 3001
# Saving frame 1061 of 3001
# Saving frame 1062 of 3001
# Saving frame 1063 of 3001
# Saving frame 1064 of 3001
# Saving frame 1065 of 3001
# Saving frame 1066 of 3001
# Saving frame 1067 of 3001
# Saving frame 1068 of 3001
# Saving frame 1069 of 3001
# Saving frame 1070 of 3001
# Saving frame 1071 of 3001
# Saving frame 1072 of 3001
# Saving frame 1073 of 3001
# Saving frame 1074 of 3001
# Saving frame 1075 of 3001
# Saving frame 1076 of 3001
# Saving frame 1077 of 3001
# Saving frame 1078 of 3001
# Saving frame 1079 of 3001
# Saving frame 1080 of 3001
# Saving frame 1081 of 3001
# Saving frame 1082 of 3001
# Saving frame 1083 of 3001
# Saving frame 1084 of 3001
# Saving frame 1085 of 3001
# Saving frame 1086 of 3001
# Saving frame 1087 of 3001
# Saving frame 1088 of 3001
# Saving frame 1089 of 3001
# Saving frame 1090 of 3001
# Saving frame 1091 of 3001
# Saving frame 1092 of 3001
# Saving frame 1093 of 3001
# Saving frame 1094 of 3001
# Saving frame 1095 of 3001
# Saving frame 1096 of 3001
# Saving frame 1097 of 3001
# Saving frame 1098 of 3001
# Saving frame 1099 of 3001
# Saving frame 1100 of 3001
# Saving frame 1101 of 3001
# Saving frame 1102 of 3001
# Saving frame 1103 of 3001
# Saving frame 1104 of 3001
# Saving frame 1105 of 3001
# Saving frame 1106 of 3001
# Saving frame 1107 of 3001
# Saving frame 1108 of 3001
# Saving frame 1109 of 3001
# Saving frame 1110 of 3001
# Saving frame 1111 of 3001
# Saving frame 1112 of 3001
# Saving frame 1113 of 3001
# Saving frame 1114 of 3001
# Saving frame 1115 of 3001
# Saving frame 1116 of 3001
# Saving frame 1117 of 3001
# Saving frame 1118 of 3001
# Saving frame 1119 of 3001
# Saving frame 1120 of 3001
# Saving frame 1121 of 3001
# Saving frame 1122 of 3001
# Saving frame 1123 of 3001
# Saving frame 1124 of 3001
# Saving frame 1125 of 3001
# Saving frame 1126 of 3001
# Saving frame 1127 of 3001
# Saving frame 1128 of 3001
# Saving frame 1129 of 3001
# Saving frame 1130 of 3001
# Saving frame 1131 of 3001
# Saving frame 1132 of 3001
# Saving frame 1133 of 3001
# Saving frame 1134 of 3001
# Saving frame 1135 of 3001
# Saving frame 1136 of 3001
# Saving frame 1137 of 3001
# Saving frame 1138 of 3001
# Saving frame 1139 of 3001
# Saving frame 1140 of 3001
# Saving frame 1141 of 3001
# Saving frame 1142 of 3001
# Saving frame 1143 of 3001
# Saving frame 1144 of 3001
# Saving frame 1145 of 3001
# Saving frame 1146 of 3001
# Saving frame 1147 of 3001
# Saving frame 1148 of 3001
# Saving frame 1149 of 3001
# Saving frame 1150 of 3001
# Saving frame 1151 of 3001
# Saving frame 1152 of 3001
# Saving frame 1153 of 3001
# Saving frame 1154 of 3001
# Saving frame 1155 of 3001
# Saving frame 1156 of 3001
# Saving frame 1157 of 3001
# Saving frame 1158 of 3001
# Saving frame 1159 of 3001
# Saving frame 1160 of 3001
# Saving frame 1161 of 3001
# Saving frame 1162 of 3001
# Saving frame 1163 of 3001
# Saving frame 1164 of 3001
# Saving frame 1165 of 3001
# Saving frame 1166 of 3001
# Saving frame 1167 of 3001
# Saving frame 1168 of 3001
# Saving frame 1169 of 3001
# Saving frame 1170 of 3001
# Saving frame 1171 of 3001
# Saving frame 1172 of 3001
# Saving frame 1173 of 3001
# Saving frame 1174 of 3001
# Saving frame 1175 of 3001
# Saving frame 1176 of 3001
# Saving frame 1177 of 3001
# Saving frame 1178 of 3001
# Saving frame 1179 of 3001
# Saving frame 1180 of 3001
# Saving frame 1181 of 3001
# Saving frame 1182 of 3001
# Saving frame 1183 of 3001
# Saving frame 1184 of 3001
# Saving frame 1185 of 3001
# Saving frame 1186 of 3001
# Saving frame 1187 of 3001
# Saving frame 1188 of 3001
# Saving frame 1189 of 3001
# Saving frame 1190 of 3001
# Saving frame 1191 of 3001
# Saving frame 1192 of 3001
# Saving frame 1193 of 3001
# Saving frame 1194 of 3001
# Saving frame 1195 of 3001
# Saving frame 1196 of 3001
# Saving frame 1197 of 3001
# Saving frame 1198 of 3001
# Saving frame 1199 of 3001
# Saving frame 1200 of 3001
# Saving frame 1201 of 3001
# Saving frame 1202 of 3001
# Saving frame 1203 of 3001
# Saving frame 1204 of 3001
# Saving frame 1205 of 3001
# Saving frame 1206 of 3001
# Saving frame 1207 of 3001
# Saving frame 1208 of 3001
# Saving frame 1209 of 3001
# Saving frame 1210 of 3001
# Saving frame 1211 of 3001
# Saving frame 1212 of 3001
# Saving frame 1213 of 3001
# Saving frame 1214 of 3001
# Saving frame 1215 of 3001
# Saving frame 1216 of 3001
# Saving frame 1217 of 3001
# Saving frame 1218 of 3001
# Saving frame 1219 of 3001
# Saving frame 1220 of 3001
# Saving frame 1221 of 3001
# Saving frame 1222 of 3001
# Saving frame 1223 of 3001
# Saving frame 1224 of 3001
# Saving frame 1225 of 3001
# Saving frame 1226 of 3001
# Saving frame 1227 of 3001
# Saving frame 1228 of 3001
# Saving frame 1229 of 3001
# Saving frame 1230 of 3001
# Saving frame 1231 of 3001
# Saving frame 1232 of 3001
# Saving frame 1233 of 3001
# Saving frame 1234 of 3001
# Saving frame 1235 of 3001
# Saving frame 1236 of 3001
# Saving frame 1237 of 3001
# Saving frame 1238 of 3001
# Saving frame 1239 of 3001
# Saving frame 1240 of 3001
# Saving frame 1241 of 3001
# Saving frame 1242 of 3001
# Saving frame 1243 of 3001
# Saving frame 1244 of 3001
# Saving frame 1245 of 3001
# Saving frame 1246 of 3001
# Saving frame 1247 of 3001
# Saving frame 1248 of 3001
# Saving frame 1249 of 3001
# Saving frame 1250 of 3001
# Saving frame 1251 of 3001
# Saving frame 1252 of 3001
# Saving frame 1253 of 3001
# Saving frame 1254 of 3001
# Saving frame 1255 of 3001
# Saving frame 1256 of 3001
# Saving frame 1257 of 3001
# Saving frame 1258 of 3001
# Saving frame 1259 of 3001
# Saving frame 1260 of 3001
# Saving frame 1261 of 3001
# Saving frame 1262 of 3001
# Saving frame 1263 of 3001
# Saving frame 1264 of 3001
# Saving frame 1265 of 3001
# Saving frame 1266 of 3001
# Saving frame 1267 of 3001
# Saving frame 1268 of 3001
# Saving frame 1269 of 3001
# Saving frame 1270 of 3001
# Saving frame 1271 of 3001
# Saving frame 1272 of 3001
# Saving frame 1273 of 3001
# Saving frame 1274 of 3001
# Saving frame 1275 of 3001
# Saving frame 1276 of 3001
# Saving frame 1277 of 3001
# Saving frame 1278 of 3001
# Saving frame 1279 of 3001
# Saving frame 1280 of 3001
# Saving frame 1281 of 3001
# Saving frame 1282 of 3001
# Saving frame 1283 of 3001
# Saving frame 1284 of 3001
# Saving frame 1285 of 3001
# Saving frame 1286 of 3001
# Saving frame 1287 of 3001
# Saving frame 1288 of 3001
# Saving frame 1289 of 3001
# Saving frame 1290 of 3001
# Saving frame 1291 of 3001
# Saving frame 1292 of 3001
# Saving frame 1293 of 3001
# Saving frame 1294 of 3001
# Saving frame 1295 of 3001
# Saving frame 1296 of 3001
# Saving frame 1297 of 3001
# Saving frame 1298 of 3001
# Saving frame 1299 of 3001
# Saving frame 1300 of 3001
# Saving frame 1301 of 3001
# Saving frame 1302 of 3001
# Saving frame 1303 of 3001
# Saving frame 1304 of 3001
# Saving frame 1305 of 3001
# Saving frame 1306 of 3001
# Saving frame 1307 of 3001
# Saving frame 1308 of 3001
# Saving frame 1309 of 3001
# Saving frame 1310 of 3001
# Saving frame 1311 of 3001
# Saving frame 1312 of 3001
# Saving frame 1313 of 3001
# Saving frame 1314 of 3001
# Saving frame 1315 of 3001
# Saving frame 1316 of 3001
# Saving frame 1317 of 3001
# Saving frame 1318 of 3001
# Saving frame 1319 of 3001
# Saving frame 1320 of 3001
# Saving frame 1321 of 3001
# Saving frame 1322 of 3001
# Saving frame 1323 of 3001
# Saving frame 1324 of 3001
# Saving frame 1325 of 3001
# Saving frame 1326 of 3001
# Saving frame 1327 of 3001
# Saving frame 1328 of 3001
# Saving frame 1329 of 3001
# Saving frame 1330 of 3001
# Saving frame 1331 of 3001
# Saving frame 1332 of 3001
# Saving frame 1333 of 3001
# Saving frame 1334 of 3001
# Saving frame 1335 of 3001
# Saving frame 1336 of 3001
# Saving frame 1337 of 3001
# Saving frame 1338 of 3001
# Saving frame 1339 of 3001
# Saving frame 1340 of 3001
# Saving frame 1341 of 3001
# Saving frame 1342 of 3001
# Saving frame 1343 of 3001
# Saving frame 1344 of 3001
# Saving frame 1345 of 3001
# Saving frame 1346 of 3001
# Saving frame 1347 of 3001
# Saving frame 1348 of 3001
# Saving frame 1349 of 3001
# Saving frame 1350 of 3001
# Saving frame 1351 of 3001
# Saving frame 1352 of 3001
# Saving frame 1353 of 3001
# Saving frame 1354 of 3001
# Saving frame 1355 of 3001
# Saving frame 1356 of 3001
# Saving frame 1357 of 3001
# Saving frame 1358 of 3001
# Saving frame 1359 of 3001
# Saving frame 1360 of 3001
# Saving frame 1361 of 3001
# Saving frame 1362 of 3001
# Saving frame 1363 of 3001
# Saving frame 1364 of 3001
# Saving frame 1365 of 3001
# Saving frame 1366 of 3001
# Saving frame 1367 of 3001
# Saving frame 1368 of 3001
# Saving frame 1369 of 3001
# Saving frame 1370 of 3001
# Saving frame 1371 of 3001
# Saving frame 1372 of 3001
# Saving frame 1373 of 3001
# Saving frame 1374 of 3001
# Saving frame 1375 of 3001
# Saving frame 1376 of 3001
# Saving frame 1377 of 3001
# Saving frame 1378 of 3001
# Saving frame 1379 of 3001
# Saving frame 1380 of 3001
# Saving frame 1381 of 3001
# Saving frame 1382 of 3001
# Saving frame 1383 of 3001
# Saving frame 1384 of 3001
# Saving frame 1385 of 3001
# Saving frame 1386 of 3001
# Saving frame 1387 of 3001
# Saving frame 1388 of 3001
# Saving frame 1389 of 3001
# Saving frame 1390 of 3001
# Saving frame 1391 of 3001
# Saving frame 1392 of 3001
# Saving frame 1393 of 3001
# Saving frame 1394 of 3001
# Saving frame 1395 of 3001
# Saving frame 1396 of 3001
# Saving frame 1397 of 3001
# Saving frame 1398 of 3001
# Saving frame 1399 of 3001
# Saving frame 1400 of 3001
# Saving frame 1401 of 3001
# Saving frame 1402 of 3001
# Saving frame 1403 of 3001
# Saving frame 1404 of 3001
# Saving frame 1405 of 3001
# Saving frame 1406 of 3001
# Saving frame 1407 of 3001
# Saving frame 1408 of 3001
# Saving frame 1409 of 3001
# Saving frame 1410 of 3001
# Saving frame 1411 of 3001
# Saving frame 1412 of 3001
# Saving frame 1413 of 3001
# Saving frame 1414 of 3001
# Saving frame 1415 of 3001
# Saving frame 1416 of 3001
# Saving frame 1417 of 3001
# Saving frame 1418 of 3001
# Saving frame 1419 of 3001
# Saving frame 1420 of 3001
# Saving frame 1421 of 3001
# Saving frame 1422 of 3001
# Saving frame 1423 of 3001
# Saving frame 1424 of 3001
# Saving frame 1425 of 3001
# Saving frame 1426 of 3001
# Saving frame 1427 of 3001
# Saving frame 1428 of 3001
# Saving frame 1429 of 3001
# Saving frame 1430 of 3001
# Saving frame 1431 of 3001
# Saving frame 1432 of 3001
# Saving frame 1433 of 3001
# Saving frame 1434 of 3001
# Saving frame 1435 of 3001
# Saving frame 1436 of 3001
# Saving frame 1437 of 3001
# Saving frame 1438 of 3001
# Saving frame 1439 of 3001
# Saving frame 1440 of 3001
# Saving frame 1441 of 3001
# Saving frame 1442 of 3001
# Saving frame 1443 of 3001
# Saving frame 1444 of 3001
# Saving frame 1445 of 3001
# Saving frame 1446 of 3001
# Saving frame 1447 of 3001
# Saving frame 1448 of 3001
# Saving frame 1449 of 3001
# Saving frame 1450 of 3001
# Saving frame 1451 of 3001
# Saving frame 1452 of 3001
# Saving frame 1453 of 3001
# Saving frame 1454 of 3001
# Saving frame 1455 of 3001
# Saving frame 1456 of 3001
# Saving frame 1457 of 3001
# Saving frame 1458 of 3001
# Saving frame 1459 of 3001
# Saving frame 1460 of 3001
# Saving frame 1461 of 3001
# Saving frame 1462 of 3001
# Saving frame 1463 of 3001
# Saving frame 1464 of 3001
# Saving frame 1465 of 3001
# Saving frame 1466 of 3001
# Saving frame 1467 of 3001
# Saving frame 1468 of 3001
# Saving frame 1469 of 3001
# Saving frame 1470 of 3001
# Saving frame 1471 of 3001
# Saving frame 1472 of 3001
# Saving frame 1473 of 3001
# Saving frame 1474 of 3001
# Saving frame 1475 of 3001
# Saving frame 1476 of 3001
# Saving frame 1477 of 3001
# Saving frame 1478 of 3001
# Saving frame 1479 of 3001
# Saving frame 1480 of 3001
# Saving frame 1481 of 3001
# Saving frame 1482 of 3001
# Saving frame 1483 of 3001
# Saving frame 1484 of 3001
# Saving frame 1485 of 3001
# Saving frame 1486 of 3001
# Saving frame 1487 of 3001
# Saving frame 1488 of 3001
# Saving frame 1489 of 3001
# Saving frame 1490 of 3001
# Saving frame 1491 of 3001
# Saving frame 1492 of 3001
# Saving frame 1493 of 3001
# Saving frame 1494 of 3001
# Saving frame 1495 of 3001
# Saving frame 1496 of 3001
# Saving frame 1497 of 3001
# Saving frame 1498 of 3001
# Saving frame 1499 of 3001
# Saving frame 1500 of 3001
# Saving frame 1501 of 3001
# Saving frame 1502 of 3001
# Saving frame 1503 of 3001
# Saving frame 1504 of 3001
# Saving frame 1505 of 3001
# Saving frame 1506 of 3001
# Saving frame 1507 of 3001
# Saving frame 1508 of 3001
# Saving frame 1509 of 3001
# Saving frame 1510 of 3001
# Saving frame 1511 of 3001
# Saving frame 1512 of 3001
# Saving frame 1513 of 3001
# Saving frame 1514 of 3001
# Saving frame 1515 of 3001
# Saving frame 1516 of 3001
# Saving frame 1517 of 3001
# Saving frame 1518 of 3001
# Saving frame 1519 of 3001
# Saving frame 1520 of 3001
# Saving frame 1521 of 3001
# Saving frame 1522 of 3001
# Saving frame 1523 of 3001
# Saving frame 1524 of 3001
# Saving frame 1525 of 3001
# Saving frame 1526 of 3001
# Saving frame 1527 of 3001
# Saving frame 1528 of 3001
# Saving frame 1529 of 3001
# Saving frame 1530 of 3001
# Saving frame 1531 of 3001
# Saving frame 1532 of 3001
# Saving frame 1533 of 3001
# Saving frame 1534 of 3001
# Saving frame 1535 of 3001
# Saving frame 1536 of 3001
# Saving frame 1537 of 3001
# Saving frame 1538 of 3001
# Saving frame 1539 of 3001
# Saving frame 1540 of 3001
# Saving frame 1541 of 3001
# Saving frame 1542 of 3001
# Saving frame 1543 of 3001
# Saving frame 1544 of 3001
# Saving frame 1545 of 3001
# Saving frame 1546 of 3001
# Saving frame 1547 of 3001
# Saving frame 1548 of 3001
# Saving frame 1549 of 3001
# Saving frame 1550 of 3001
# Saving frame 1551 of 3001
# Saving frame 1552 of 3001
# Saving frame 1553 of 3001
# Saving frame 1554 of 3001
# Saving frame 1555 of 3001
# Saving frame 1556 of 3001
# Saving frame 1557 of 3001
# Saving frame 1558 of 3001
# Saving frame 1559 of 3001
# Saving frame 1560 of 3001
# Saving frame 1561 of 3001
# Saving frame 1562 of 3001
# Saving frame 1563 of 3001
# Saving frame 1564 of 3001
# Saving frame 1565 of 3001
# Saving frame 1566 of 3001
# Saving frame 1567 of 3001
# Saving frame 1568 of 3001
# Saving frame 1569 of 3001
# Saving frame 1570 of 3001
# Saving frame 1571 of 3001
# Saving frame 1572 of 3001
# Saving frame 1573 of 3001
# Saving frame 1574 of 3001
# Saving frame 1575 of 3001
# Saving frame 1576 of 3001
# Saving frame 1577 of 3001
# Saving frame 1578 of 3001
# Saving frame 1579 of 3001
# Saving frame 1580 of 3001
# Saving frame 1581 of 3001
# Saving frame 1582 of 3001
# Saving frame 1583 of 3001
# Saving frame 1584 of 3001
# Saving frame 1585 of 3001
# Saving frame 1586 of 3001
# Saving frame 1587 of 3001
# Saving frame 1588 of 3001
# Saving frame 1589 of 3001
# Saving frame 1590 of 3001
# Saving frame 1591 of 3001
# Saving frame 1592 of 3001
# Saving frame 1593 of 3001
# Saving frame 1594 of 3001
# Saving frame 1595 of 3001
# Saving frame 1596 of 3001
# Saving frame 1597 of 3001
# Saving frame 1598 of 3001
# Saving frame 1599 of 3001
# Saving frame 1600 of 3001
# Saving frame 1601 of 3001
# Saving frame 1602 of 3001
# Saving frame 1603 of 3001
# Saving frame 1604 of 3001
# Saving frame 1605 of 3001
# Saving frame 1606 of 3001
# Saving frame 1607 of 3001
# Saving frame 1608 of 3001
# Saving frame 1609 of 3001
# Saving frame 1610 of 3001
# Saving frame 1611 of 3001
# Saving frame 1612 of 3001
# Saving frame 1613 of 3001
# Saving frame 1614 of 3001
# Saving frame 1615 of 3001
# Saving frame 1616 of 3001
# Saving frame 1617 of 3001
# Saving frame 1618 of 3001
# Saving frame 1619 of 3001
# Saving frame 1620 of 3001
# Saving frame 1621 of 3001
# Saving frame 1622 of 3001
# Saving frame 1623 of 3001
# Saving frame 1624 of 3001
# Saving frame 1625 of 3001
# Saving frame 1626 of 3001
# Saving frame 1627 of 3001
# Saving frame 1628 of 3001
# Saving frame 1629 of 3001
# Saving frame 1630 of 3001
# Saving frame 1631 of 3001
# Saving frame 1632 of 3001
# Saving frame 1633 of 3001
# Saving frame 1634 of 3001
# Saving frame 1635 of 3001
# Saving frame 1636 of 3001
# Saving frame 1637 of 3001
# Saving frame 1638 of 3001
# Saving frame 1639 of 3001
# Saving frame 1640 of 3001
# Saving frame 1641 of 3001
# Saving frame 1642 of 3001
# Saving frame 1643 of 3001
# Saving frame 1644 of 3001
# Saving frame 1645 of 3001
# Saving frame 1646 of 3001
# Saving frame 1647 of 3001
# Saving frame 1648 of 3001
# Saving frame 1649 of 3001
# Saving frame 1650 of 3001
# Saving frame 1651 of 3001
# Saving frame 1652 of 3001
# Saving frame 1653 of 3001
# Saving frame 1654 of 3001
# Saving frame 1655 of 3001
# Saving frame 1656 of 3001
# Saving frame 1657 of 3001
# Saving frame 1658 of 3001
# Saving frame 1659 of 3001
# Saving frame 1660 of 3001
# Saving frame 1661 of 3001
# Saving frame 1662 of 3001
# Saving frame 1663 of 3001
# Saving frame 1664 of 3001
# Saving frame 1665 of 3001
# Saving frame 1666 of 3001
# Saving frame 1667 of 3001
# Saving frame 1668 of 3001
# Saving frame 1669 of 3001
# Saving frame 1670 of 3001
# Saving frame 1671 of 3001
# Saving frame 1672 of 3001
# Saving frame 1673 of 3001
# Saving frame 1674 of 3001
# Saving frame 1675 of 3001
# Saving frame 1676 of 3001
# Saving frame 1677 of 3001
# Saving frame 1678 of 3001
# Saving frame 1679 of 3001
# Saving frame 1680 of 3001
# Saving frame 1681 of 3001
# Saving frame 1682 of 3001
# Saving frame 1683 of 3001
# Saving frame 1684 of 3001
# Saving frame 1685 of 3001
# Saving frame 1686 of 3001
# Saving frame 1687 of 3001
# Saving frame 1688 of 3001
# Saving frame 1689 of 3001
# Saving frame 1690 of 3001
# Saving frame 1691 of 3001
# Saving frame 1692 of 3001
# Saving frame 1693 of 3001
# Saving frame 1694 of 3001
# Saving frame 1695 of 3001
# Saving frame 1696 of 3001
# Saving frame 1697 of 3001
# Saving frame 1698 of 3001
# Saving frame 1699 of 3001
# Saving frame 1700 of 3001
# Saving frame 1701 of 3001
# Saving frame 1702 of 3001
# Saving frame 1703 of 3001
# Saving frame 1704 of 3001
# Saving frame 1705 of 3001
# Saving frame 1706 of 3001
# Saving frame 1707 of 3001
# Saving frame 1708 of 3001
# Saving frame 1709 of 3001
# Saving frame 1710 of 3001
# Saving frame 1711 of 3001
# Saving frame 1712 of 3001
# Saving frame 1713 of 3001
# Saving frame 1714 of 3001
# Saving frame 1715 of 3001
# Saving frame 1716 of 3001
# Saving frame 1717 of 3001
# Saving frame 1718 of 3001
# Saving frame 1719 of 3001
# Saving frame 1720 of 3001
# Saving frame 1721 of 3001
# Saving frame 1722 of 3001
# Saving frame 1723 of 3001
# Saving frame 1724 of 3001
# Saving frame 1725 of 3001
# Saving frame 1726 of 3001
# Saving frame 1727 of 3001
# Saving frame 1728 of 3001
# Saving frame 1729 of 3001
# Saving frame 1730 of 3001
# Saving frame 1731 of 3001
# Saving frame 1732 of 3001
# Saving frame 1733 of 3001
# Saving frame 1734 of 3001
# Saving frame 1735 of 3001
# Saving frame 1736 of 3001
# Saving frame 1737 of 3001
# Saving frame 1738 of 3001
# Saving frame 1739 of 3001
# Saving frame 1740 of 3001
# Saving frame 1741 of 3001
# Saving frame 1742 of 3001
# Saving frame 1743 of 3001
# Saving frame 1744 of 3001
# Saving frame 1745 of 3001
# Saving frame 1746 of 3001
# Saving frame 1747 of 3001
# Saving frame 1748 of 3001
# Saving frame 1749 of 3001
# Saving frame 1750 of 3001
# Saving frame 1751 of 3001
# Saving frame 1752 of 3001
# Saving frame 1753 of 3001
# Saving frame 1754 of 3001
# Saving frame 1755 of 3001
# Saving frame 1756 of 3001
# Saving frame 1757 of 3001
# Saving frame 1758 of 3001
# Saving frame 1759 of 3001
# Saving frame 1760 of 3001
# Saving frame 1761 of 3001
# Saving frame 1762 of 3001
# Saving frame 1763 of 3001
# Saving frame 1764 of 3001
# Saving frame 1765 of 3001
# Saving frame 1766 of 3001
# Saving frame 1767 of 3001
# Saving frame 1768 of 3001
# Saving frame 1769 of 3001
# Saving frame 1770 of 3001
# Saving frame 1771 of 3001
# Saving frame 1772 of 3001
# Saving frame 1773 of 3001
# Saving frame 1774 of 3001
# Saving frame 1775 of 3001
# Saving frame 1776 of 3001
# Saving frame 1777 of 3001
# Saving frame 1778 of 3001
# Saving frame 1779 of 3001
# Saving frame 1780 of 3001
# Saving frame 1781 of 3001
# Saving frame 1782 of 3001
# Saving frame 1783 of 3001
# Saving frame 1784 of 3001
# Saving frame 1785 of 3001
# Saving frame 1786 of 3001
# Saving frame 1787 of 3001
# Saving frame 1788 of 3001
# Saving frame 1789 of 3001
# Saving frame 1790 of 3001
# Saving frame 1791 of 3001
# Saving frame 1792 of 3001
# Saving frame 1793 of 3001
# Saving frame 1794 of 3001
# Saving frame 1795 of 3001
# Saving frame 1796 of 3001
# Saving frame 1797 of 3001
# Saving frame 1798 of 3001
# Saving frame 1799 of 3001
# Saving frame 1800 of 3001
# Saving frame 1801 of 3001
# Saving frame 1802 of 3001
# Saving frame 1803 of 3001
# Saving frame 1804 of 3001
# Saving frame 1805 of 3001
# Saving frame 1806 of 3001
# Saving frame 1807 of 3001
# Saving frame 1808 of 3001
# Saving frame 1809 of 3001
# Saving frame 1810 of 3001
# Saving frame 1811 of 3001
# Saving frame 1812 of 3001
# Saving frame 1813 of 3001
# Saving frame 1814 of 3001
# Saving frame 1815 of 3001
# Saving frame 1816 of 3001
# Saving frame 1817 of 3001
# Saving frame 1818 of 3001
# Saving frame 1819 of 3001
# Saving frame 1820 of 3001
# Saving frame 1821 of 3001
# Saving frame 1822 of 3001
# Saving frame 1823 of 3001
# Saving frame 1824 of 3001
# Saving frame 1825 of 3001
# Saving frame 1826 of 3001
# Saving frame 1827 of 3001
# Saving frame 1828 of 3001
# Saving frame 1829 of 3001
# Saving frame 1830 of 3001
# Saving frame 1831 of 3001
# Saving frame 1832 of 3001
# Saving frame 1833 of 3001
# Saving frame 1834 of 3001
# Saving frame 1835 of 3001
# Saving frame 1836 of 3001
# Saving frame 1837 of 3001
# Saving frame 1838 of 3001
# Saving frame 1839 of 3001
# Saving frame 1840 of 3001
# Saving frame 1841 of 3001
# Saving frame 1842 of 3001
# Saving frame 1843 of 3001
# Saving frame 1844 of 3001
# Saving frame 1845 of 3001
# Saving frame 1846 of 3001
# Saving frame 1847 of 3001
# Saving frame 1848 of 3001
# Saving frame 1849 of 3001
# Saving frame 1850 of 3001
# Saving frame 1851 of 3001
# Saving frame 1852 of 3001
# Saving frame 1853 of 3001
# Saving frame 1854 of 3001
# Saving frame 1855 of 3001
# Saving frame 1856 of 3001
# Saving frame 1857 of 3001
# Saving frame 1858 of 3001
# Saving frame 1859 of 3001
# Saving frame 1860 of 3001
# Saving frame 1861 of 3001
# Saving frame 1862 of 3001
# Saving frame 1863 of 3001
# Saving frame 1864 of 3001
# Saving frame 1865 of 3001
# Saving frame 1866 of 3001
# Saving frame 1867 of 3001
# Saving frame 1868 of 3001
# Saving frame 1869 of 3001
# Saving frame 1870 of 3001
# Saving frame 1871 of 3001
# Saving frame 1872 of 3001
# Saving frame 1873 of 3001
# Saving frame 1874 of 3001
# Saving frame 1875 of 3001
# Saving frame 1876 of 3001
# Saving frame 1877 of 3001
# Saving frame 1878 of 3001
# Saving frame 1879 of 3001
# Saving frame 1880 of 3001
# Saving frame 1881 of 3001
# Saving frame 1882 of 3001
# Saving frame 1883 of 3001
# Saving frame 1884 of 3001
# Saving frame 1885 of 3001
# Saving frame 1886 of 3001
# ...
# Saving frame 2387 of 3001
# Saving frame 2388 of 3001
# Saving frame 2389 of 3001
# Saving frame 2390 of 3001
# Saving frame 2391 of 3001
# Saving frame 2392 of 3001
# Saving frame 2393 of 3001
# Saving frame 2394 of 3001
# Saving frame 2395 of 3001
# Saving frame 2396 of 3001
# Saving frame 2397 of 3001
# Saving frame 2398 of 3001
# Saving frame 2399 of 3001
# Saving frame 2400 of 3001
# Saving frame 2401 of 3001
# Saving frame 2402 of 3001
# Saving frame 2403 of 3001
# Saving frame 2404 of 3001
# Saving frame 2405 of 3001
# Saving frame 2406 of 3001
# Saving frame 2407 of 3001
# Saving frame 2408 of 3001
# Saving frame 2409 of 3001
# Saving frame 2410 of 3001
# Saving frame 2411 of 3001
# Saving frame 2412 of 3001
# Saving frame 2413 of 3001
# Saving frame 2414 of 3001
# Saving frame 2415 of 3001
# Saving frame 2416 of 3001
# Saving frame 2417 of 3001
# Saving frame 2418 of 3001
# Saving frame 2419 of 3001
# Saving frame 2420 of 3001
# Saving frame 2421 of 3001
# Saving frame 2422 of 3001
# Saving frame 2423 of 3001
# Saving frame 2424 of 3001
# Saving frame 2425 of 3001
# Saving frame 2426 of 3001
# Saving frame 2427 of 3001
# Saving frame 2428 of 3001
# Saving frame 2429 of 3001
# Saving frame 2430 of 3001
# Saving frame 2431 of 3001
# Saving frame 2432 of 3001
# Saving frame 2433 of 3001
# Saving frame 2434 of 3001
# Saving frame 2435 of 3001
# Saving frame 2436 of 3001
# Saving frame 2437 of 3001
# Saving frame 2438 of 3001
# Saving frame 2439 of 3001
# Saving frame 2440 of 3001
# Saving frame 2441 of 3001
# Saving frame 2442 of 3001
# Saving frame 2443 of 3001
# Saving frame 2444 of 3001
# Saving frame 2445 of 3001
# Saving frame 2446 of 3001
# Saving frame 2447 of 3001
# Saving frame 2448 of 3001
# Saving frame 2449 of 3001
# Saving frame 2450 of 3001
# Saving frame 2451 of 3001
# Saving frame 2452 of 3001
# Saving frame 2453 of 3001
# Saving frame 2454 of 3001
# Saving frame 2455 of 3001
# Saving frame 2456 of 3001
# Saving frame 2457 of 3001
# Saving frame 2458 of 3001
# Saving frame 2459 of 3001
# Saving frame 2460 of 3001
# Saving frame 2461 of 3001
# Saving frame 2462 of 3001
# Saving frame 2463 of 3001
# Saving frame 2464 of 3001
# Saving frame 2465 of 3001
# Saving frame 2466 of 3001
# Saving frame 2467 of 3001
# Saving frame 2468 of 3001
# Saving frame 2469 of 3001
# Saving frame 2470 of 3001
# Saving frame 2471 of 3001
# Saving frame 2472 of 3001
# Saving frame 2473 of 3001
# Saving frame 2474 of 3001
# Saving frame 2475 of 3001
# Saving frame 2476 of 3001
# Saving frame 2477 of 3001
# Saving frame 2478 of 3001
# Saving frame 2479 of 3001
# Saving frame 2480 of 3001
# Saving frame 2481 of 3001
# Saving frame 2482 of 3001
# Saving frame 2483 of 3001
# Saving frame 2484 of 3001
# Saving frame 2485 of 3001
# Saving frame 2486 of 3001
# Saving frame 2487 of 3001
# Saving frame 2488 of 3001
# Saving frame 2489 of 3001
# Saving frame 2490 of 3001
# Saving frame 2491 of 3001
# Saving frame 2492 of 3001
# Saving frame 2493 of 3001
# Saving frame 2494 of 3001
# Saving frame 2495 of 3001
# Saving frame 2496 of 3001
# Saving frame 2497 of 3001
# Saving frame 2498 of 3001
# Saving frame 2499 of 3001
# Saving frame 2500 of 3001
# Saving frame 2501 of 3001
# Saving frame 2502 of 3001
# Saving frame 2503 of 3001
# Saving frame 2504 of 3001
# Saving frame 2505 of 3001
# Saving frame 2506 of 3001
# Saving frame 2507 of 3001
# Saving frame 2508 of 3001
# Saving frame 2509 of 3001
# Saving frame 2510 of 3001
# Saving frame 2511 of 3001
# Saving frame 2512 of 3001
# Saving frame 2513 of 3001
# Saving frame 2514 of 3001
# Saving frame 2515 of 3001
# Saving frame 2516 of 3001
# Saving frame 2517 of 3001
# Saving frame 2518 of 3001
# Saving frame 2519 of 3001
# Saving frame 2520 of 3001
# Saving frame 2521 of 3001
# Saving frame 2522 of 3001
# Saving frame 2523 of 3001
# Saving frame 2524 of 3001
# Saving frame 2525 of 3001
# Saving frame 2526 of 3001
# Saving frame 2527 of 3001
# Saving frame 2528 of 3001
# Saving frame 2529 of 3001
# Saving frame 2530 of 3001
# Saving frame 2531 of 3001
# Saving frame 2532 of 3001
# Saving frame 2533 of 3001
# Saving frame 2534 of 3001
# Saving frame 2535 of 3001
# Saving frame 2536 of 3001
# Saving frame 2537 of 3001
# Saving frame 2538 of 3001
# Saving frame 2539 of 3001
# Saving frame 2540 of 3001
# Saving frame 2541 of 3001
# Saving frame 2542 of 3001
# Saving frame 2543 of 3001
# Saving frame 2544 of 3001
# Saving frame 2545 of 3001
# Saving frame 2546 of 3001
# Saving frame 2547 of 3001
# Saving frame 2548 of 3001
# Saving frame 2549 of 3001
# Saving frame 2550 of 3001
# Saving frame 2551 of 3001
# Saving frame 2552 of 3001
# Saving frame 2553 of 3001
# Saving frame 2554 of 3001
# Saving frame 2555 of 3001
# Saving frame 2556 of 3001
# Saving frame 2557 of 3001
# Saving frame 2558 of 3001
# Saving frame 2559 of 3001
# Saving frame 2560 of 3001
# Saving frame 2561 of 3001
# Saving frame 2562 of 3001
# Saving frame 2563 of 3001
# Saving frame 2564 of 3001
# Saving frame 2565 of 3001
# Saving frame 2566 of 3001
# Saving frame 2567 of 3001
# Saving frame 2568 of 3001
# Saving frame 2569 of 3001
# Saving frame 2570 of 3001
# Saving frame 2571 of 3001
# Saving frame 2572 of 3001
# Saving frame 2573 of 3001
# Saving frame 2574 of 3001
# Saving frame 2575 of 3001
# Saving frame 2576 of 3001
# Saving frame 2577 of 3001
# Saving frame 2578 of 3001
# Saving frame 2579 of 3001
# Saving frame 2580 of 3001
# Saving frame 2581 of 3001
# Saving frame 2582 of 3001
# Saving frame 2583 of 3001
# Saving frame 2584 of 3001
# Saving frame 2585 of 3001
# Saving frame 2586 of 3001
# Saving frame 2587 of 3001
# Saving frame 2588 of 3001
# Saving frame 2589 of 3001
# Saving frame 2590 of 3001
# Saving frame 2591 of 3001
# Saving frame 2592 of 3001
# Saving frame 2593 of 3001
# Saving frame 2594 of 3001
# Saving frame 2595 of 3001
# Saving frame 2596 of 3001
# Saving frame 2597 of 3001
# Saving frame 2598 of 3001
# Saving frame 2599 of 3001
# Saving frame 2600 of 3001
# Saving frame 2601 of 3001
# Saving frame 2602 of 3001
# Saving frame 2603 of 3001
# Saving frame 2604 of 3001
# Saving frame 2605 of 3001
# Saving frame 2606 of 3001
# Saving frame 2607 of 3001
# Saving frame 2608 of 3001
# Saving frame 2609 of 3001
# Saving frame 2610 of 3001
# Saving frame 2611 of 3001
# Saving frame 2612 of 3001
# Saving frame 2613 of 3001
# Saving frame 2614 of 3001
# Saving frame 2615 of 3001
# Saving frame 2616 of 3001
# Saving frame 2617 of 3001
# Saving frame 2618 of 3001
# Saving frame 2619 of 3001
# Saving frame 2620 of 3001
# Saving frame 2621 of 3001
# Saving frame 2622 of 3001
# Saving frame 2623 of 3001
# Saving frame 2624 of 3001
# Saving frame 2625 of 3001
# Saving frame 2626 of 3001
# Saving frame 2627 of 3001
# Saving frame 2628 of 3001
# Saving frame 2629 of 3001
# Saving frame 2630 of 3001
# Saving frame 2631 of 3001
# Saving frame 2632 of 3001
# Saving frame 2633 of 3001
# Saving frame 2634 of 3001
# Saving frame 2635 of 3001
# Saving frame 2636 of 3001
# Saving frame 2637 of 3001
# Saving frame 2638 of 3001
# Saving frame 2639 of 3001
# Saving frame 2640 of 3001
# Saving frame 2641 of 3001
# Saving frame 2642 of 3001
# Saving frame 2643 of 3001
# Saving frame 2644 of 3001
# Saving frame 2645 of 3001
# Saving frame 2646 of 3001
# Saving frame 2647 of 3001
# Saving frame 2648 of 3001
# Saving frame 2649 of 3001
# Saving frame 2650 of 3001
# Saving frame 2651 of 3001
# Saving frame 2652 of 3001
# Saving frame 2653 of 3001
# Saving frame 2654 of 3001
# Saving frame 2655 of 3001
# Saving frame 2656 of 3001
# Saving frame 2657 of 3001
# Saving frame 2658 of 3001
# Saving frame 2659 of 3001
# Saving frame 2660 of 3001
# Saving frame 2661 of 3001
# Saving frame 2662 of 3001
# Saving frame 2663 of 3001
# Saving frame 2664 of 3001
# Saving frame 2665 of 3001
# Saving frame 2666 of 3001
# Saving frame 2667 of 3001
# Saving frame 2668 of 3001
# Saving frame 2669 of 3001
# Saving frame 2670 of 3001
# Saving frame 2671 of 3001
# Saving frame 2672 of 3001
# Saving frame 2673 of 3001
# Saving frame 2674 of 3001
# Saving frame 2675 of 3001
# Saving frame 2676 of 3001
# Saving frame 2677 of 3001
# Saving frame 2678 of 3001
# Saving frame 2679 of 3001
# Saving frame 2680 of 3001
# Saving frame 2681 of 3001
# Saving frame 2682 of 3001
# Saving frame 2683 of 3001
# Saving frame 2684 of 3001
# Saving frame 2685 of 3001
# Saving frame 2686 of 3001
# Saving frame 2687 of 3001
# Saving frame 2688 of 3001
# Saving frame 2689 of 3001
# Saving frame 2690 of 3001
# Saving frame 2691 of 3001
# Saving frame 2692 of 3001
# Saving frame 2693 of 3001
# Saving frame 2694 of 3001
# Saving frame 2695 of 3001
# Saving frame 2696 of 3001
# Saving frame 2697 of 3001
# Saving frame 2698 of 3001
# Saving frame 2699 of 3001
# Saving frame 2700 of 3001
# Saving frame 2701 of 3001
# Saving frame 2702 of 3001
# Saving frame 2703 of 3001
# Saving frame 2704 of 3001
# Saving frame 2705 of 3001
# Saving frame 2706 of 3001
# Saving frame 2707 of 3001
# Saving frame 2708 of 3001
# Saving frame 2709 of 3001
# Saving frame 2710 of 3001
# Saving frame 2711 of 3001
# Saving frame 2712 of 3001
# Saving frame 2713 of 3001
# Saving frame 2714 of 3001
# Saving frame 2715 of 3001
# Saving frame 2716 of 3001
# Saving frame 2717 of 3001
# Saving frame 2718 of 3001
# Saving frame 2719 of 3001
# Saving frame 2720 of 3001
# Saving frame 2721 of 3001
# Saving frame 2722 of 3001
# Saving frame 2723 of 3001
# Saving frame 2724 of 3001
# Saving frame 2725 of 3001
# Saving frame 2726 of 3001
# Saving frame 2727 of 3001
# Saving frame 2728 of 3001
# Saving frame 2729 of 3001
# Saving frame 2730 of 3001
# Saving frame 2731 of 3001
# Saving frame 2732 of 3001
# Saving frame 2733 of 3001
# Saving frame 2734 of 3001
# Saving frame 2735 of 3001
# Saving frame 2736 of 3001
# Saving frame 2737 of 3001
# Saving frame 2738 of 3001
# Saving frame 2739 of 3001
# Saving frame 2740 of 3001
# Saving frame 2741 of 3001
# Saving frame 2742 of 3001
# Saving frame 2743 of 3001
# Saving frame 2744 of 3001
# Saving frame 2745 of 3001
# Saving frame 2746 of 3001
# Saving frame 2747 of 3001
# Saving frame 2748 of 3001
# Saving frame 2749 of 3001
# Saving frame 2750 of 3001
# Saving frame 2751 of 3001
# Saving frame 2752 of 3001
# Saving frame 2753 of 3001
# Saving frame 2754 of 3001
# Saving frame 2755 of 3001
# Saving frame 2756 of 3001
# Saving frame 2757 of 3001
# Saving frame 2758 of 3001
# Saving frame 2759 of 3001
# Saving frame 2760 of 3001
# Saving frame 2761 of 3001
# Saving frame 2762 of 3001
# Saving frame 2763 of 3001
# Saving frame 2764 of 3001
# Saving frame 2765 of 3001
# Saving frame 2766 of 3001
# Saving frame 2767 of 3001
# Saving frame 2768 of 3001
# Saving frame 2769 of 3001
# Saving frame 2770 of 3001
# Saving frame 2771 of 3001
# Saving frame 2772 of 3001
# Saving frame 2773 of 3001
# Saving frame 2774 of 3001
# Saving frame 2775 of 3001
# Saving frame 2776 of 3001
# Saving frame 2777 of 3001
# Saving frame 2778 of 3001
# Saving frame 2779 of 3001
# Saving frame 2780 of 3001
# Saving frame 2781 of 3001
# Saving frame 2782 of 3001
# Saving frame 2783 of 3001
# Saving frame 2784 of 3001
# Saving frame 2785 of 3001
# Saving frame 2786 of 3001
# Saving frame 2787 of 3001
# Saving frame 2788 of 3001
# Saving frame 2789 of 3001
# Saving frame 2790 of 3001
# Saving frame 2791 of 3001
# Saving frame 2792 of 3001
# Saving frame 2793 of 3001
# Saving frame 2794 of 3001
# Saving frame 2795 of 3001
# Saving frame 2796 of 3001
# Saving frame 2797 of 3001
# Saving frame 2798 of 3001
# Saving frame 2799 of 3001
# Saving frame 2800 of 3001
# Saving frame 2801 of 3001
# Saving frame 2802 of 3001
# Saving frame 2803 of 3001
# Saving frame 2804 of 3001
# Saving frame 2805 of 3001
# Saving frame 2806 of 3001
# Saving frame 2807 of 3001
# Saving frame 2808 of 3001
# Saving frame 2809 of 3001
# Saving frame 2810 of 3001
# Saving frame 2811 of 3001
# Saving frame 2812 of 3001
# Saving frame 2813 of 3001
# Saving frame 2814 of 3001
# Saving frame 2815 of 3001
# Saving frame 2816 of 3001
# Saving frame 2817 of 3001
# Saving frame 2818 of 3001
# Saving frame 2819 of 3001
# Saving frame 2820 of 3001
# Saving frame 2821 of 3001
# Saving frame 2822 of 3001
# Saving frame 2823 of 3001
# Saving frame 2824 of 3001
# Saving frame 2825 of 3001
# Saving frame 2826 of 3001
# Saving frame 2827 of 3001
# Saving frame 2828 of 3001
# Saving frame 2829 of 3001
# Saving frame 2830 of 3001
# Saving frame 2831 of 3001
# Saving frame 2832 of 3001
# Saving frame 2833 of 3001
# Saving frame 2834 of 3001
# Saving frame 2835 of 3001
# Saving frame 2836 of 3001
# Saving frame 2837 of 3001
# Saving frame 2838 of 3001
# Saving frame 2839 of 3001
# Saving frame 2840 of 3001
# Saving frame 2841 of 3001
# Saving frame 2842 of 3001
# Saving frame 2843 of 3001
# Saving frame 2844 of 3001
# Saving frame 2845 of 3001
# Saving frame 2846 of 3001
# Saving frame 2847 of 3001
# Saving frame 2848 of 3001
# Saving frame 2849 of 3001
# Saving frame 2850 of 3001
# Saving frame 2851 of 3001
# Saving frame 2852 of 3001
# Saving frame 2853 of 3001
# Saving frame 2854 of 3001
# Saving frame 2855 of 3001
# Saving frame 2856 of 3001
# Saving frame 2857 of 3001
# Saving frame 2858 of 3001
# Saving frame 2859 of 3001
# Saving frame 2860 of 3001
# Saving frame 2861 of 3001
# Saving frame 2862 of 3001
# Saving frame 2863 of 3001
# Saving frame 2864 of 3001
# Saving frame 2865 of 3001
# Saving frame 2866 of 3001
# Saving frame 2867 of 3001
# Saving frame 2868 of 3001
# Saving frame 2869 of 3001
# Saving frame 2870 of 3001
# Saving frame 2871 of 3001
# Saving frame 2872 of 3001
# Saving frame 2873 of 3001
# Saving frame 2874 of 3001
# Saving frame 2875 of 3001
# Saving frame 2876 of 3001
# Saving frame 2877 of 3001
# Saving frame 2878 of 3001
# Saving frame 2879 of 3001
# Saving frame 2880 of 3001
# Saving frame 2881 of 3001
# Saving frame 2882 of 3001
# Saving frame 2883 of 3001
# Saving frame 2884 of 3001
# Saving frame 2885 of 3001
# Saving frame 2886 of 3001
# Saving frame 2887 of 3001
# Saving frame 2888 of 3001
# Saving frame 2889 of 3001
# Saving frame 2890 of 3001
# Saving frame 2891 of 3001
# Saving frame 2892 of 3001
# Saving frame 2893 of 3001
# Saving frame 2894 of 3001
# Saving frame 2895 of 3001
# Saving frame 2896 of 3001
# Saving frame 2897 of 3001
# Saving frame 2898 of 3001
# Saving frame 2899 of 3001
# Saving frame 2900 of 3001
# Saving frame 2901 of 3001
# Saving frame 2902 of 3001
# Saving frame 2903 of 3001
# Saving frame 2904 of 3001
# Saving frame 2905 of 3001
# Saving frame 2906 of 3001
# Saving frame 2907 of 3001
# Saving frame 2908 of 3001
# Saving frame 2909 of 3001
# Saving frame 2910 of 3001
# Saving frame 2911 of 3001
# Saving frame 2912 of 3001
# Saving frame 2913 of 3001
# Saving frame 2914 of 3001
# Saving frame 2915 of 3001
# Saving frame 2916 of 3001
# Saving frame 2917 of 3001
# Saving frame 2918 of 3001
# Saving frame 2919 of 3001
# Saving frame 2920 of 3001
# Saving frame 2921 of 3001
# Saving frame 2922 of 3001
# Saving frame 2923 of 3001
# Saving frame 2924 of 3001
# Saving frame 2925 of 3001
# Saving frame 2926 of 3001
# Saving frame 2927 of 3001
# Saving frame 2928 of 3001
# Saving frame 2929 of 3001
# Saving frame 2930 of 3001
# Saving frame 2931 of 3001
# Saving frame 2932 of 3001
# Saving frame 2933 of 3001
# Saving frame 2934 of 3001
# Saving frame 2935 of 3001
# Saving frame 2936 of 3001
# Saving frame 2937 of 3001
# Saving frame 2938 of 3001
# Saving frame 2939 of 3001
# Saving frame 2940 of 3001
# Saving frame 2941 of 3001
# Saving frame 2942 of 3001
# Saving frame 2943 of 3001
# Saving frame 2944 of 3001
# Saving frame 2945 of 3001
# Saving frame 2946 of 3001
# Saving frame 2947 of 3001
# Saving frame 2948 of 3001
# Saving frame 2949 of 3001
# Saving frame 2950 of 3001
# Saving frame 2951 of 3001
# Saving frame 2952 of 3001
# Saving frame 2953 of 3001
# Saving frame 2954 of 3001
# Saving frame 2955 of 3001
# Saving frame 2956 of 3001
# Saving frame 2957 of 3001
# Saving frame 2958 of 3001
# Saving frame 2959 of 3001
# Saving frame 2960 of 3001
# Saving frame 2961 of 3001
# Saving frame 2962 of 3001
# Saving frame 2963 of 3001
# Saving frame 2964 of 3001
# Saving frame 2965 of 3001
# Saving frame 2966 of 3001
# Saving frame 2967 of 3001
# Saving frame 2968 of 3001
# Saving frame 2969 of 3001
# Saving frame 2970 of 3001
# Saving frame 2971 of 3001
# Saving frame 2972 of 3001
# Saving frame 2973 of 3001
# Saving frame 2974 of 3001
# Saving frame 2975 of 3001
# Saving frame 2976 of 3001
# Saving frame 2977 of 3001
# Saving frame 2978 of 3001
# Saving frame 2979 of 3001
# Saving frame 2980 of 3001
# Saving frame 2981 of 3001
# Saving frame 2982 of 3001
# Saving frame 2983 of 3001
# Saving frame 2984 of 3001
# Saving frame 2985 of 3001
# Saving frame 2986 of 3001
# Saving frame 2987 of 3001
# Saving frame 2988 of 3001
# Saving frame 2989 of 3001
# Saving frame 2990 of 3001
# Saving frame 2991 of 3001
# Saving frame 2992 of 3001
# Saving frame 2993 of 3001
# Saving frame 2994 of 3001
# Saving frame 2995 of 3001
# Saving frame 2996 of 3001
# Saving frame 2997 of 3001
# Saving frame 2998 of 3001
# Saving frame 2999 of 3001
# Saving frame 3000 of 3001
# Saving frame 3001 of 3001
