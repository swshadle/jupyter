# %%
""" Kepler's Laws-2nd Law 2
Equal areas swept out in equal time
"""
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.legend_handler import HandlerPatch
from matplotlib.animation import FuncAnimation
from matplotlib.animation import FFMpegWriter
import matplotlib.patches as mpatches
from matplotlib.collections import PatchCollection
from math import floor, factorial
# %matplotlib notebook
with plt.xkcd():
    from matplotlib import patheffects
    plt.style.use(['dark_background'])
    plt.xkcd()
    plt.rcParams['path.effects'] = [patheffects.withStroke(linewidth=0)]
    plt.rcParams['figure.facecolor'] = 'black'
    # explanation of path.sketch from the docstring of the xkcd function
    # scale = 1  # amplitude of the wiggle
    # length = 100  # length of the wiggle along the line
    # randomness = 2  # scale factor for shrinking and expanding the length
    plt.rcParams['path.sketch'] = (0.6, 100, 2)

    TWOPI = 2*np.pi # numpy doesn't have tau (2π)

    plt.style.use('dark_background')
    fig = plt.figure(figsize=(6.7, 5), dpi=100)
    # xyticklabels=[-2,-1,0,1,2]
    xyticklabels=[]
    ax = plt.subplot(1,1,1,frameon=False,xticks=xyticklabels,yticks=xyticklabels,xlim=(-1.05,1.8),ylim=(-1.1,1.1))
    ax.set_yticklabels(xyticklabels)
    ax.set_xticklabels(xyticklabels)

    # e is eccentricity of the ellipse. e = |cf|/a, where |cf| is the distance from the center to a focus (=h, assuming no tilt) and a is the semimajor axis
    e = 0.7
    a = 1.0    # a is the semi-major axis

    # Finding semi-minor axis, b given semi-major axis, a and eccentricity, e
    b = a*(1-e**2)**0.5

    # given a & e, you can find the focal distance c using e = c/a or c = ea
    c = e*a

    # given a & e and having calculated b, we can find horizontal offset, h, and vertical, k
    if b<a:
        k = 0
        h = (a**2-b**2)**0.5
    elif a<b:
        h = 0
        k = (b**2-a**2)**0.5
    else: # a==b
        h = k = 0

    datapoints = 12000 # number of points to use for drawing the ellipse
    datastepsize = TWOPI/datapoints
    playbackpoints = 300
    #1200-151 # number of points to use when animating the planet
    playbackstepsize = TWOPI/playbackpoints

    # theta is the angle at the center of the ellipse from periapsis to a helper point, y, on the auxilliary circle
    theta = np.arange(0.0, TWOPI+datastepsize/2, datastepsize)

    # find the eccentric anomaly (angle) based on the mean anomaly
    def EA(M, n):
        EA = M
        for k in range(n):
            EA = EA + (M + e*np.sin(EA) - EA)*(1+e*np.cos(EA))/(1-e**2*(np.cos(EA))**2)
        return EA

    """ graveyard of failed formulas to find eccentric anomaly:
        theta = M + 2*e*sin(M) + (5/4)*e**2*sin(2*M) + e**3*((13/12)*sin(3*M)-(1/4)*sin(M)) # not sure why this doesn't work but ok, i'll step through M
        theta = np.zeros(datapoints, dtype=float)
        for i in M:
        #     theta[i] = M[i] + 2*e*sin(M[i]) + (5/4)*e**2*sin(2*M[i]) + e**3*((13/12)*sin(3*M[i])-(1/4)*sin(M[i]))
            print(f'step {i}: M[i]={M[i]} θ[i]={theta[i]}')
        with np.nditer(theta, op_flags=['readwrite']) as it:
            for m in it:
                m[...] = E(m, 1000)
               m[...] = m + m + (2*e-(1/4)*e**3)*np.sin(m)+((5/4)*e**2)*np.sin(2*m)+((13/12)*e**3)*np.sin(3*m)
                m[...] = m + 2*e*np.sin(m) + (5/4)*e**2*np.sin(2*m) + e**3*((13/12)*np.sin(3*m)-(1/4)*np.sin(m))
                m[...] = TWOPI*(1+2*e*np.cos(m)+(5/2)*e**2*np.cos(2*m)+e**3*((13/4)*np.cos(3*m)-(1/4)*np.cos(m)))
        M = np.arange(0.0, TWOPI, datastepsize) # M is Newton's Mean Anomoly, values from 0 to 2π in increments of datastepsize
            analytical solution from Tokis, A Solution of Kepler’s Equation, https://www.scirp.org/pdf/IJAA_2014123013365071.pdf
        E = M + (e**2-(1-(1-e)*(1+e*M**2/(1-e)**3)**0.5)**2)**0.5
        # given mean anomaly, return the eccentric anomaly, from http://pepijndevos.nl/2015/02/05/simulating-the-solar-system.html
        def solve_kepler(eccentricity, mean_anomaly):
            # for the approximate formulae in the present context, tol = 10e-6 degrees is sufficient
            tolerance = 10e-6
            # E0 = M + e sin M
            eccentric_anomaly = mean_anomaly + (eccentricity * np.sin(mean_anomaly))
            # and iterate the following equations with n = 0,1,2,... until |delta E| <= tol
            while True:
                ax.set_title('M={:.3} E={:.3} ∆E={:.3} e={:.3}'.format(mean_anomaly,eccentric_anomaly,delta_eccentric_anomaly,e),fontsize=12)
                # delta M = M - (En - e sin En)
                delta_mean_anomaly = mean_anomaly - (eccentric_anomaly - (eccentricity * math.sin(eccentric_anomaly)))
                # delta E = delta M / (1 - e cos En)
                delta_eccentric_anomaly = delta_mean_anomaly / (1 - (eccentricity * math.cos(eccentric_anomaly)))
                # En+1 = En + delta E
                eccentric_anomaly += delta_eccentric_anomaly
                 print('eccentric anomaly: {} ∆: {}'.format(eccentric_anomaly, delta_eccentric_anomaly))
                if abs(delta_eccentric_anomaly) <= tolerance:
                    return eccentric_anomaly

        E = solve_kepler(e, M)
        E = M + 2*e*np.sin(M) + (5/4)*e**2*np.sin(2*M) + e**3*((13/12)*np.sin(3*M)-(1/4)*np.sin(M))
        E = M+ (e**2-(1-(1-e)*(1+e*M**2/(1-e)**3)**0.5)**2)**0.5 # eqs. 40 & 41 from Tokis, A Solution of Kepler’s Equation
        .
        .
        .
        sigh...
    """
    # calculate x and y for a circle in cartesian coordinates:
    xcircle = np.cos(theta)
    ycircle = np.sin(theta)

    xellipse = xcircle       # ellipse x values from -1 to 1
    yellipse = (b/a)*ycircle # ellipse y values from -1 to 1

    ax.set_aspect('equal') # makes the circle look like a circle
    #     cir = plt.plot(xcircle, ycircle, 'k-', linewidth=0.1, label='auxiliary circle')
    #     ell = plt.plot(xellipse, yellipse, 'b-', linewidth=0.5, label='ellipse (e={:.3})'.format(e))
    # ell = plt.plot(xellipse, yellipse, 'w-', linewidth=0.5, label='ellipse')
    ell = plt.plot(xellipse, yellipse, 'w-', linewidth=1)

    # quick experiment to find which coordinates to use for text
    # for i in range(10):
    #     ax.text(i/10, 1-i/10, 'left top at {}'.format(i/10),
    #         horizontalalignment='left',
    #         verticalalignment='top',
    #         transform=ax.transAxes)

    # 'a=semimajor axis'
    # ax.text(0.77, 0.35, 'a=semi-major axis',
    #         horizontalalignment='left',
    #         verticalalignment='top',
    #         transform=ax.transAxes,
    #         fontsize='large',
    #        )

    # 'b=semiminor axis'
    # ax.text(0.77, 0.28, 'b=semi-minor axis',
    #         horizontalalignment='left',
    #         verticalalignment='top',
    #         transform=ax.transAxes,
    #         fontsize='large',
    #        )

    # make a polygon to show the area swept out by the planet in a month
    # xy_pPoly = [(h,0), (a,0)] # (x,y) starting point for the swept area polygon located at periapsis
    xy_pPoly = [(h,0), (h,0)] # (x,y) starting point for the swept area polygon located at periapsis
    pPoly = mpatches.Polygon(xy_pPoly, closed=True, edgecolor=None, facecolor='xkcd:light green', alpha=0.15, animated=False)
    # aLine,  = plt.plot((0,xcircle[0]), (0,ycircle[0]), 'k:', linewidth=0.5) # static line from center to periapsis
    #     xpLine, = plt.plot((xcircle[0],xellipse[0]), (ycircle[0],yellipse[0]), 'k:', linewidth=0.5) # line connecting point x with planet p
#     p2Line, = plt.plot((h,xellipse[0]),(k,yellipse[0]), '-', color='green', linewidth=0.5) # line connecting the sun and planet
    pLine,  = plt.plot((h,xellipse[0]),(k,yellipse[0]), '-', color='lightgreen', linewidth=0.5) # line connecting the sun and planet
    # yLine,  = plt.plot((0,xcircle[0]), (0,ycircle[0]), 'w:', linewidth=0.5) # moves with yDot showing mean anomaly
    # bLine,  = plt.plot((0,0), (0,b*np.sin(np.pi/2)), 'w:', linewidth=0.5) # static (not animated)
    #     xDot,   = plt.plot([xcircle[0]], [ycircle[0]], 'r.', markersize=10) # helper of angle==ecc. anomaly along circle
    #     yDot,   = plt.plot([xcircle[0]], [ycircle[0]], 'g.', markersize=10) # helper of angle==mean anomaly along circle
    pDot,   = plt.plot([xellipse[0]], [yellipse[0]], '.', color='lightgreen', markersize=25, label='planet') # location of planet
    p2Dot,  = plt.plot([xellipse[0]], [yellipse[0]], '.', color='green', markersize=25, label='planet one month later') # location of planet
    # focus0  = plt.plot(-h, -k, 'w. ', markersize=2, label='empty focus') # location of the "empty" focus
    # focus1  = plt.plot(h, k, 'y* ', markersize=20, label='star at focus') # plot the location of the star next (so it appears above the "empty" focus if they overlap)
    focus0  = plt.plot(-h, -k, 'w. ', markersize=2,) # location of the "empty" focus
    focus1  = plt.plot(h, k, 'y* ', markersize=20) # plot the location of the star next (so it appears above the "empty" focus if they overlap)
    # make a polygon to show the area of the wedge described by focus1-periapsis-xDot
    #     xyPoly = [(h,0), (a,0)] # (x,y) starting point for the polygon located at periapsis
    #     xPoly = mpatches.Polygon(xyPoly, closed=True, edgecolor="black", facecolor='xkcd:light blue', alpha=0.1, label='area of x wedge =', animated=False)

    # and a wedge described by the center-periapsis-yDot
    #     yWedge = mpatches.Wedge(center=(0,0), r=1, theta1=0, theta2=0, edgecolor="black", facecolor='xkcd:very light purple', alpha=0.1, label='area of y wedge', animated=False)

    # Wedge and Polygon patches don't get added to the legend automatically so we'll have to do it
    handles, labels = ax.get_legend_handles_labels()
    #     handles.append(xPoly)
    #     handles.append(yWedge)
    plt.legend(bbox_to_anchor=(1.08, 1), # bbox_to_anchor lets you set the legend outside the figure
               handles=handles,          # our updated list of handles
               loc='upper right',
               ncol=1,
               fontsize='small',
               borderaxespad=0.0,
               shadow=True,
              )

    xy = (xcircle[0], ycircle[0]) # initial location of labels for xDot and yDot

    #     xDotAnnotation = ax.annotate('x',
    #                                  xy=xy,  xycoords='data',
    #                                  xytext=xy, textcoords='data',
    #                                  horizontalalignment='center', verticalalignment='center',
    #                                 )

    #     yDotAnnotation = ax.annotate('y',
    #                                  xy=xy,  xycoords='data',
    #                                  xytext=xy, textcoords='data',
    #                                  horizontalalignment='center', verticalalignment='center',
    #                                 )

    # yLineAnnotation = ax.annotate('a',
    #                              xy=xy,  xycoords='data',
    #                              xytext=(xy[0]/2,xy[1]/2), textcoords='data',
    #                              horizontalalignment='right', verticalalignment='top',
    #                             )

    # bLineAnnotation = ax.annotate('b',
    #                              xy=(0, 0),  xycoords='data',
    #                              xytext=(0, b*np.sin(np.pi/2)/2), textcoords='data',
    #                              horizontalalignment='right', verticalalignment='center',
    #                              )

    # Create the init function that returns the objects that will change during the animation process
    def init():
    #     ax.set_title(f'{xy_pPoly}',fontsize=12)
        xy_pPoly.pop()
        # building up datapoints for pPoly, the wedge of area swept out in a month
        for i in range(playbackpoints//12):
            M = i*playbackstepsize
            E = EA(M,20)
            xx = xcircle[floor((E/datastepsize)%datapoints)] # x position for xdot
            yx = ycircle[floor((E/datastepsize)%datapoints)] # y position for xdot
            xp = xx
            yp = yx*b/a # find the location of the planet, pDot by dropping the location of xDot vertically onto the ellipse
            xy_pPoly.append((xp, yp))

        pPoly.set_xy(xy_pPoly)
        ax.add_patch(pPoly)

    #     ax.add_patch(pPoly)
    #         ax.add_patch(xPoly)
    #         ax.add_patch(yWedge)
        return pDot, p2Dot, pLine, pPoly
    #         return pDot, yDot, yDotAnnotation, yLine, yLineAnnotation, xDot, xDotAnnotation, xpLine, pLine, xPoly, yWedge

    """
    Note that the value at x[-1] yields the last value in the numpy ndarray x.

    It's the same value as x[floor(1000*TWOPI)], so when we want to reference various
    values of x and y based on the iterator i with values from 0 to 2π the index of the
    array x or y is the floor of 1000*i. It's times 1000 because we initially used a step
    size of 1/1000 or 0.001. In the general case, it would be x[floor(i/datastepsize)].
    """

    def animate(radians):
        M = (radians+TWOPI+TWOPI/12)%TWOPI       # M is the mean anomaly
        M2= radians #M2 is mean anomaly 1 month (1/12 of the circle) later
        E = EA(M,20)
        E2= EA(M2,20)

        xx = xcircle[floor((E/datastepsize)%datapoints)] # x position for xdot
        yx = ycircle[floor((E/datastepsize)%datapoints)] # y position for xdot

        xx2= xcircle[floor((E2/datastepsize)%datapoints)] # x position for xdot 1 month later
        yx2= ycircle[floor((E2/datastepsize)%datapoints)] # y position for xdot 1 month later

    #         if (radians<TWOPI): # grow shapes on 1st pass
    #             xyPoly.append((xx, yx))
    #             yWedge.set_theta2(M*360/TWOPI)
    #         else:               # shrink shapes on 2nd pass
    #             del(xyPoly[1])  # delete the 2nd item in the list because deleting xyPoly[0] removes the focus
    #             yWedge.set_theta1(M*360/TWOPI)

    #     xy = xcircle[floor((M/datastepsize)%datapoints)] # x position for ydot
    #     yy = ycircle[floor((M/datastepsize)%datapoints)] # y position for ydot

        xp = xx
        yp = yx*b/a # find the location of the planet, pDot by dropping the location of xDot vertically onto the ellipse

        xy_pPoly.append((xp, yp))


    #     pPoly.append((xp, yp))

        xp2= xx2
        yp2= yx2*b/a # location of the planet one month later

    #     xy_pPoly.remove((xp2, yp2))
#         del(xy_pPoly[1])


    #         yDotAnnotation.set_position((xy*1.1, yy*1.1)) # set the annotation outside the circle
    #         yLine.set_data((0,xy), (0,yy))
    #         yLineAnnotation.set_position((xy/2, yy/2))
    #         yDot.set_data(xy, yy)
    #         xDotAnnotation.set_position((xx*1.1, yx*1.1))
    #         xpLine.set_data((xx,xp), (yx,yp))
    #         xDot.set_data(xx, yx)
        pDot.set_data(xp,yp)
        p2Dot.set_data(xp2,yp2)
        pLine.set_data((h,xp),(k,yp))
#         p2Line.set_data((h,xp2),(k,yp2))
        pPoly.set_xy(xy_pPoly)
        del(xy_pPoly[1])
    #         xPoly.set_xy(xyPoly)

        return pDot, p2Dot, pLine, pPoly
    #         return pDot, yDot, yDotAnnotation, yLine, yLineAnnotation, xDot, xDotAnnotation, xpLine, pLine, xPoly, yWedge

    progress_callback = lambda i, n: print(f'Saving frame {i+1} of {n}')
    animation = FuncAnimation(fig, animate, 
                              frames=np.arange(0.0, TWOPI, playbackstepsize), # run the animation once around the circle
                              interval=1, blit=False, repeat=False, init_func=init)

    writer = FFMpegWriter(fps=15, metadata=dict(artist='Stephen Shadle'), bitrate=1800)
    animation.save("kepler's 2nd law.{:^2.2f}.{}.mp4".format(e,playbackpoints), writer=writer, 
                   progress_callback=progress_callback
                 ) #current directoryanimate
# Out:
# <img src="data:image/png;base64,..." width="670">
# Saving frame 1 of 300
# Saving frame 2 of 300
# Saving frame 3 of 300
# Saving frame 4 of 300
# Saving frame 5 of 300
# Saving frame 6 of 300
# Saving frame 7 of 300
# Saving frame 8 of 300
# Saving frame 9 of 300
# Saving frame 10 of 300
# Saving frame 11 of 300
# Saving frame 12 of 300
# Saving frame 13 of 300
# Saving frame 14 of 300
# Saving frame 15 of 300
# Saving frame 16 of 300
# Saving frame 17 of 300
# Saving frame 18 of 300
# Saving frame 19 of 300
# Saving frame 20 of 300
# Saving frame 21 of 300
# Saving frame 22 of 300
# Saving frame 23 of 300
# Saving frame 24 of 300
# Saving frame 25 of 300
# Saving frame 26 of 300
# Saving frame 27 of 300
# Saving frame 28 of 300
# Saving frame 29 of 300
# Saving frame 30 of 300
# Saving frame 31 of 300
# Saving frame 32 of 300
# Saving frame 33 of 300
# Saving frame 34 of 300
# Saving frame 35 of 300
# Saving frame 36 of 300
# Saving frame 37 of 300
# Saving frame 38 of 300
# Saving frame 39 of 300
# Saving frame 40 of 300
# Saving frame 41 of 300
# Saving frame 42 of 300
# Saving frame 43 of 300
# Saving frame 44 of 300
# Saving frame 45 of 300
# Saving frame 46 of 300
# Saving frame 47 of 300
# Saving frame 48 of 300
# Saving frame 49 of 300
# Saving frame 50 of 300
# Saving frame 51 of 300
# Saving frame 52 of 300
# Saving frame 53 of 300
# Saving frame 54 of 300
# Saving frame 55 of 300
# Saving frame 56 of 300
# Saving frame 57 of 300
# Saving frame 58 of 300
# Saving frame 59 of 300
# Saving frame 60 of 300
# Saving frame 61 of 300
# Saving frame 62 of 300
# Saving frame 63 of 300
# Saving frame 64 of 300
# Saving frame 65 of 300
# Saving frame 66 of 300
# Saving frame 67 of 300
# Saving frame 68 of 300
# Saving frame 69 of 300
# Saving frame 70 of 300
# Saving frame 71 of 300
# Saving frame 72 of 300
# Saving frame 73 of 300
# Saving frame 74 of 300
# Saving frame 75 of 300
# Saving frame 76 of 300
# Saving frame 77 of 300
# Saving frame 78 of 300
# Saving frame 79 of 300
# Saving frame 80 of 300
# Saving frame 81 of 300
# Saving frame 82 of 300
# Saving frame 83 of 300
# Saving frame 84 of 300
# Saving frame 85 of 300
# Saving frame 86 of 300
# Saving frame 87 of 300
# Saving frame 88 of 300
# Saving frame 89 of 300
# Saving frame 90 of 300
# Saving frame 91 of 300
# Saving frame 92 of 300
# Saving frame 93 of 300
# Saving frame 94 of 300
# Saving frame 95 of 300
# Saving frame 96 of 300
# Saving frame 97 of 300
# Saving frame 98 of 300
# Saving frame 99 of 300
# Saving frame 100 of 300
# Saving frame 101 of 300
# Saving frame 102 of 300
# Saving frame 103 of 300
# Saving frame 104 of 300
# Saving frame 105 of 300
# Saving frame 106 of 300
# Saving frame 107 of 300
# Saving frame 108 of 300
# Saving frame 109 of 300
# Saving frame 110 of 300
# Saving frame 111 of 300
# Saving frame 112 of 300
# Saving frame 113 of 300
# Saving frame 114 of 300
# Saving frame 115 of 300
# Saving frame 116 of 300
# Saving frame 117 of 300
# Saving frame 118 of 300
# Saving frame 119 of 300
# Saving frame 120 of 300
# Saving frame 121 of 300
# Saving frame 122 of 300
# Saving frame 123 of 300
# Saving frame 124 of 300
# Saving frame 125 of 300
# Saving frame 126 of 300
# Saving frame 127 of 300
# Saving frame 128 of 300
# Saving frame 129 of 300
# Saving frame 130 of 300
# Saving frame 131 of 300
# Saving frame 132 of 300
# Saving frame 133 of 300
# Saving frame 134 of 300
# Saving frame 135 of 300
# Saving frame 136 of 300
# Saving frame 137 of 300
# Saving frame 138 of 300
# Saving frame 139 of 300
# Saving frame 140 of 300
# Saving frame 141 of 300
# Saving frame 142 of 300
# Saving frame 143 of 300
# Saving frame 144 of 300
# Saving frame 145 of 300
# Saving frame 146 of 300
# Saving frame 147 of 300
# Saving frame 148 of 300
# Saving frame 149 of 300
# Saving frame 150 of 300
# Saving frame 151 of 300
# Saving frame 152 of 300
# Saving frame 153 of 300
# Saving frame 154 of 300
# Saving frame 155 of 300
# Saving frame 156 of 300
# Saving frame 157 of 300
# Saving frame 158 of 300
# Saving frame 159 of 300
# Saving frame 160 of 300
# Saving frame 161 of 300
# Saving frame 162 of 300
# Saving frame 163 of 300
# Saving frame 164 of 300
# Saving frame 165 of 300
# Saving frame 166 of 300
# Saving frame 167 of 300
# Saving frame 168 of 300
# Saving frame 169 of 300
# Saving frame 170 of 300
# Saving frame 171 of 300
# Saving frame 172 of 300
# Saving frame 173 of 300
# Saving frame 174 of 300
# Saving frame 175 of 300
# Saving frame 176 of 300
# Saving frame 177 of 300
# Saving frame 178 of 300
# Saving frame 179 of 300
# Saving frame 180 of 300
# Saving frame 181 of 300
# Saving frame 182 of 300
# Saving frame 183 of 300
# Saving frame 184 of 300
# Saving frame 185 of 300
# Saving frame 186 of 300
# Saving frame 187 of 300
# Saving frame 188 of 300
# Saving frame 189 of 300
# Saving frame 190 of 300
# Saving frame 191 of 300
# Saving frame 192 of 300
# Saving frame 193 of 300
# Saving frame 194 of 300
# Saving frame 195 of 300
# Saving frame 196 of 300
# Saving frame 197 of 300
# Saving frame 198 of 300
# Saving frame 199 of 300
# Saving frame 200 of 300
# Saving frame 201 of 300
# Saving frame 202 of 300
# Saving frame 203 of 300
# Saving frame 204 of 300
# Saving frame 205 of 300
# Saving frame 206 of 300
# Saving frame 207 of 300
# Saving frame 208 of 300
# Saving frame 209 of 300
# Saving frame 210 of 300
# Saving frame 211 of 300
# Saving frame 212 of 300
# Saving frame 213 of 300
# Saving frame 214 of 300
# Saving frame 215 of 300
# Saving frame 216 of 300
# Saving frame 217 of 300
# Saving frame 218 of 300
# Saving frame 219 of 300
# Saving frame 220 of 300
# Saving frame 221 of 300
# Saving frame 222 of 300
# Saving frame 223 of 300
# Saving frame 224 of 300
# Saving frame 225 of 300
# Saving frame 226 of 300
# Saving frame 227 of 300
# Saving frame 228 of 300
# Saving frame 229 of 300
# Saving frame 230 of 300
# Saving frame 231 of 300
# Saving frame 232 of 300
# Saving frame 233 of 300
# Saving frame 234 of 300
# Saving frame 235 of 300
# Saving frame 236 of 300
# Saving frame 237 of 300
# Saving frame 238 of 300
# Saving frame 239 of 300
# Saving frame 240 of 300
# Saving frame 241 of 300
# Saving frame 242 of 300
# Saving frame 243 of 300
# Saving frame 244 of 300
# Saving frame 245 of 300
# Saving frame 246 of 300
# Saving frame 247 of 300
# Saving frame 248 of 300
# Saving frame 249 of 300
# Saving frame 250 of 300
# Saving frame 251 of 300
# Saving frame 252 of 300
# Saving frame 253 of 300
# Saving frame 254 of 300
# Saving frame 255 of 300
# Saving frame 256 of 300
# Saving frame 257 of 300
# Saving frame 258 of 300
# Saving frame 259 of 300
# Saving frame 260 of 300
# Saving frame 261 of 300
# Saving frame 262 of 300
# Saving frame 263 of 300
# Saving frame 264 of 300
# Saving frame 265 of 300
# Saving frame 266 of 300
# Saving frame 267 of 300
# Saving frame 268 of 300
# Saving frame 269 of 300
# Saving frame 270 of 300
# Saving frame 271 of 300
# Saving frame 272 of 300
# Saving frame 273 of 300
# Saving frame 274 of 300
# Saving frame 275 of 300
# Saving frame 276 of 300
# Saving frame 277 of 300
# Saving frame 278 of 300
# Saving frame 279 of 300
# Saving frame 280 of 300
# Saving frame 281 of 300
# Saving frame 282 of 300
# Saving frame 283 of 300
# Saving frame 284 of 300
# Saving frame 285 of 300
# Saving frame 286 of 300
# Saving frame 287 of 300
# Saving frame 288 of 300
# Saving frame 289 of 300
# Saving frame 290 of 300
# Saving frame 291 of 300
# Saving frame 292 of 300
# Saving frame 293 of 300
# Saving frame 294 of 300
# Saving frame 295 of 300
# Saving frame 296 of 300
# Saving frame 297 of 300
# Saving frame 298 of 300
# Saving frame 299 of 300
# Saving frame 300 of 300
